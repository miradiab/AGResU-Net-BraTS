# %%
# ============================================================
# Cell 1: Setup, GPU check, imports, and folders
# ============================================================

import os
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf

# We use a fixed seed so the split and training are more reproducible
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Check TensorFlow and GPU
print("TensorFlow:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))

if tf.config.list_physical_devices("GPU"):
    print("GPU is available.")
else:
    print("No GPU found. Please enable GPU in Colab.")

PROJECT_DIR = Path.home() / "brats_project"
OUTPUT_DIR = PROJECT_DIR / "outputs"
PROCESSED_DIR = PROJECT_DIR / "processed"

PROJECT_DIR.mkdir(parents=True, exist_ok=True)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

print("PROJECT_DIR:", PROJECT_DIR)
print("OUTPUT_DIR:", OUTPUT_DIR)
print("PROCESSED_DIR:", PROCESSED_DIR)

# Main experiment settings
PATCH_SIZE = 128
NUM_CLASSES = 4
EPOCHS = 20
BATCH_SIZE = 2

print("Patch size:", PATCH_SIZE)
print("Classes:", NUM_CLASSES)
print("Epochs:", EPOCHS)
print("Batch size:", BATCH_SIZE)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778702277.374850     868 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1778702277.861125     868 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778702279.530927     868 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# TensorFlow: 2.21.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU is available.
# PROJECT_DIR: /home/zak/brats_project
# OUTPUT_DIR: /home/zak/brats_project/outputs
# PROCESSED_DIR: /home/zak/brats_project/processed
# Patch size: 128
# Classes: 4
# Epochs: 20
# Batch size: 2

# %%
# ============================================================
# Cell 2: Load already-downloaded BraTS 2017, 2018, 2019
# ============================================================

import os
from pathlib import Path

import nibabel as nib
from sklearn.model_selection import train_test_split
from tqdm import tqdm

print("Libraries are ready.")

DATASET_PATHS = {
    "brats2017": Path.home() / "brats_project" / "data" / "brats17",
    "brats2018": Path.home() / "brats_project" / "data" / "brats2018",
    "brats2019": Path.home() / "brats_project" / "data" / "brats2019",
}

for dataset_name, dataset_path in DATASET_PATHS.items():
    print("\nDataset:", dataset_name)
    print("Path:", dataset_path)
    print("Folder exists:", dataset_path.exists())

    if not dataset_path.exists():
        raise FileNotFoundError(f"Dataset folder not found: {dataset_path}")

    print("First items:")
    for item in list(dataset_path.iterdir())[:10]:
        print("-", item.name)
# Out:
# Libraries are ready.
#
# Dataset: brats2017
# Path: /home/zak/brats_project/data/brats17
# Folder exists: True
# First items:
# - BRATS2017
#
# Dataset: brats2018
# Path: /home/zak/brats_project/data/brats2018
# Folder exists: True
# First items:
# - MICCAI_BraTS_2018_Data_Training
# - mean_std_dict.pickle
# - MICCAI_BraTS_2018_Data_Validation
# - checkpoint
#
# Dataset: brats2019
# Path: /home/zak/brats_project/data/brats2019
# Folder exists: True
# First items:
# - MICCAI_BraTS_2019_Data_Training

# %%
# ============================================================
# Cell 3: Find patients and split them for each dataset separately
# ============================================================

def is_complete_patient(folder):
    files = [f.lower() for f in os.listdir(folder)]

    has_flair = any("flair" in f for f in files)
    has_t1ce  = any("t1ce" in f for f in files)
    has_t1    = any("t1" in f and "t1ce" not in f for f in files)
    has_t2    = any("t2" in f for f in files)
    has_seg   = any("seg" in f for f in files)

    return has_flair and has_t1 and has_t1ce and has_t2 and has_seg


def find_file(folder, name_part):
    for f in os.listdir(folder):
        name = f.lower()

        if name_part == "t1":
            if "t1" in name and "t1ce" not in name:
                return os.path.join(folder, f)

        elif name_part in name:
            return os.path.join(folder, f)

    return None


def find_all_patients(dataset_path):
    patient_dirs = []

    for root, dirs, files in os.walk(dataset_path):
        if is_complete_patient(root):
            patient_dirs.append(root)

    patient_dirs = sorted(patient_dirs)
    return patient_dirs


def split_patients(patient_dirs):
    train_patients, temp_patients = train_test_split(
        patient_dirs,
        test_size=0.40,
        random_state=SEED,
        shuffle=True
    )

    val_patients, test_patients = train_test_split(
        temp_patients,
        test_size=0.50,
        random_state=SEED,
        shuffle=True
    )

    return train_patients, val_patients, test_patients


DATASET_SPLITS = {}

for dataset_name, dataset_path in DATASET_PATHS.items():
    print("\n" + "=" * 60)
    print("Preparing:", dataset_name)
    print("=" * 60)

    patient_dirs = find_all_patients(dataset_path)

    print("Total complete patients found:", len(patient_dirs))

    print("\nFirst 5 patients:")
    for p in patient_dirs[:5]:
        print("-", p.split("/")[-1])

    train_patients, val_patients, test_patients = split_patients(patient_dirs)

    DATASET_SPLITS[dataset_name] = {
        "all_patients": patient_dirs,
        "train_patients": train_patients,
        "val_patients": val_patients,
        "test_patients": test_patients
    }

    split_table = pd.DataFrame({
        "Dataset": [dataset_name, dataset_name, dataset_name],
        "Set": ["Train", "Validation", "Test"],
        "Patients": [
            len(train_patients),
            len(val_patients),
            len(test_patients)
        ]
    })

    display(split_table)

    if len(patient_dirs) > 0:
        print("\nFiles inside first patient:")
        for f in sorted(os.listdir(patient_dirs[0])):
            print("-", f)
# Out:
# ============================================================
# Preparing: brats2017
# ============================================================
# Total complete patients found: 285
#
# First 5 patients:
# - Brats17_2013_10_1
# - Brats17_2013_11_1
# - Brats17_2013_12_1
# - Brats17_2013_13_1
# - Brats17_2013_14_1
#      Dataset         Set  Patients
# 0  brats2017       Train       171
# 1  brats2017  Validation        57
# 2  brats2017        Test        57
# Files inside first patient:
# - Brats17_2013_10_1_flair.nii
# - Brats17_2013_10_1_seg.nii
# - Brats17_2013_10_1_t1.nii
# - Brats17_2013_10_1_t1ce.nii
# - Brats17_2013_10_1_t2.nii
# - ROI_Brats17_2013_10_1_t1.nii
#
# ============================================================
# Preparing: brats2018
# ============================================================
# Total complete patients found: 285
#
# First 5 patients:
# - Brats18_2013_10_1
# - Brats18_2013_11_1
# - Brats18_2013_12_1
# - Brats18_2013_13_1
# - Brats18_2013_14_1
#      Dataset         Set  Patients
# 0  brats2018       Train       171
# 1  brats2018  Validation        57
# 2  brats2018        Test        57
# Files inside first patient:
# - Brats18_2013_10_1_flair.nii
# - Brats18_2013_10_1_seg.nii
# - Brats18_2013_10_1_t1.nii
# - Brats18_2013_10_1_t1ce.nii
# - Brats18_2013_10_1_t2.nii
#
# ============================================================
# Preparing: brats2019
# ============================================================
# Total complete patients found: 335
#
# First 5 patients:
# - BraTS19_001
# - BraTS19_002
# - BraTS19_003
# - BraTS19_004
# - BraTS19_005
#      Dataset         Set  Patients
# 0  brats2019       Train       201
# 1  brats2019  Validation        67
# 2  brats2019        Test        67
# Files inside first patient:
# - BraTS19_001_flair.nii
# - BraTS19_001_seg.nii
# - BraTS19_001_t1.nii
# - BraTS19_001_t1ce.nii
# - BraTS19_001_t2.nii

# %%
# ============================================================
# Cell 4: Preprocessing helper functions
# ============================================================

def normalize_mri(img):
    # Normalize only the brain area, not the black background
    mask = img > 0
    img = img.copy()

    if np.sum(mask) > 0:
        low, high = np.percentile(img[mask], [1, 99])
        img[mask] = np.clip(img[mask], low, high)

        mean = img[mask].mean()
        std = img[mask].std()

        img[mask] = (img[mask] - mean) / (std + 1e-8)
        img[~mask] = 0

    return img


def crop_center(img, size=128):
    # Take the middle 128x128 part of the slice
    h, w = img.shape[:2]

    start_h = (h - size) // 2
    start_w = (w - size) // 2

    return img[start_h:start_h+size, start_w:start_w+size]


def load_patient_volume(patient):
    # Load the 4 MRI modalities and the segmentation mask
    flair = nib.load(find_file(patient, "flair")).get_fdata().astype("float32")
    t1    = nib.load(find_file(patient, "t1")).get_fdata().astype("float32")
    t1ce  = nib.load(find_file(patient, "t1ce")).get_fdata().astype("float32")
    t2    = nib.load(find_file(patient, "t2")).get_fdata().astype("float32")
    seg   = nib.load(find_file(patient, "seg")).get_fdata().astype("uint8")

    # Apply z-score normalization to each MRI modality
    flair = normalize_mri(flair)
    t1    = normalize_mri(t1)
    t1ce  = normalize_mri(t1ce)
    t2    = normalize_mri(t2)

    # Stack the 4 modalities into one 4-channel volume
    x_vol = np.stack([flair, t1, t1ce, t2], axis=-1).astype("float32")

    # BraTS labels are 0, 1, 2, 4.
    # For softmax training, we change them to 0, 1, 2, 3.
    seg = seg.copy()
    seg[seg == 4] = 3

    return x_vol, seg


def make_slice_sample(x_vol, seg_vol, slice_id):
    # Take one axial slice from the MRI volume and mask
    x_slice = x_vol[:, :, slice_id, :]
    y_slice = seg_vol[:, :, slice_id]

    # Crop to 128x128
    x_slice = crop_center(x_slice, PATCH_SIZE)
    y_slice = crop_center(y_slice, PATCH_SIZE)

    # One-hot encode the mask
    y_onehot = tf.keras.utils.to_categorical(
        y_slice,
        num_classes=NUM_CLASSES
    ).astype("float32")

    return x_slice.astype("float32"), y_onehot


# Quick sanity check using one training patient
x_vol, seg_vol = load_patient_volume(train_patients[0])

print("Loaded patient:", train_patients[0].split("/")[-1])
print("MRI volume shape:", x_vol.shape)
print("Segmentation shape:", seg_vol.shape)
print("Segmentation labels:", np.unique(seg_vol))
print("MRI min/max:", x_vol.min(), x_vol.max())

# Pick the slice with the most tumor for checking
tumor_per_slice = np.sum(seg_vol > 0, axis=(0, 1))
slice_id = int(np.argmax(tumor_per_slice))

X_check, y_check = make_slice_sample(x_vol, seg_vol, slice_id)

print("\nSelected slice:", slice_id)
print("Tumor pixels:", tumor_per_slice[slice_id])
print("X_check shape:", X_check.shape)
print("y_check shape:", y_check.shape)
print("Mask labels:", np.unique(np.argmax(y_check, axis=-1)))
# Out:
# Loaded patient: BraTS19_069
# MRI volume shape: (240, 240, 155, 4)
# Segmentation shape: (240, 240, 155)
# Segmentation labels: [0 1 2 3]
# MRI min/max: -2.304516 4.0326204
#
# Selected slice: 53
# Tumor pixels: 2508
# X_check shape: (128, 128, 4)
# y_check shape: (128, 128, 4)
# Mask labels: [0 1 2 3]

# %%
# ============================================================
# NEW CELL after Cell 4:
# Preprocess raw NIfTI patients -> saved .npy patients
# ============================================================

SAVE_DTYPE = np.float16

BAD_PATIENTS = {
    "Brats17_2013_2_1"   # known corrupted BraTS17 case
}

def safe_patient_name(patient_dir):
    return Path(patient_dir).name.replace(" ", "_").replace("/", "_")


def get_valid_slice_indices(mask_vol, min_tumor_pixels=20):
    return [
        z for z in range(mask_vol.shape[2])
        if np.sum(mask_vol[:, :, z] > 0) >= min_tumor_pixels
    ]


def preprocess_patient_to_npy(patient_dir, out_root):
    patient_dir = Path(patient_dir)

    if patient_dir.name in BAD_PATIENTS:
        print("Skipping known bad patient:", patient_dir.name)
        return None

    patient_name = safe_patient_name(patient_dir)

    out_dir = out_root / patient_name
    out_dir.mkdir(parents=True, exist_ok=True)

    img_path = out_dir / "image_4ch.npy"
    mask_path = out_dir / "mask.npy"
    valid_path = out_dir / "valid_slices.npy"

    # Skip if already processed
    if img_path.exists() and mask_path.exists() and valid_path.exists():
        return out_dir

    image_4ch, mask = load_patient_volume(str(patient_dir))

    np.save(img_path, image_4ch.astype(SAVE_DTYPE))
    np.save(mask_path, mask.astype(np.uint8))

    valid_slices = np.array(
        get_valid_slice_indices(mask, min_tumor_pixels=20),
        dtype=np.int16
    )

    np.save(valid_path, valid_slices)

    return out_dir


def preprocess_dataset_to_npy(dataset_name, patient_dirs):
    out_root = PROCESSED_DIR / dataset_name
    out_root.mkdir(parents=True, exist_ok=True)

    processed_dirs = []

    print(f"Preprocessing {dataset_name} → {out_root}")

    for p in tqdm(patient_dirs):
        try:
            processed_dir = preprocess_patient_to_npy(p, out_root)
            if processed_dir is not None:
                processed_dirs.append(processed_dir)
        except Exception as e:
            print("Failed:", p)
            print(e)

    print(f"Done. Processed patients: {len(processed_dirs)}")
    return sorted(processed_dirs)

# %%
processed_patients = {}

processed_patients["brats2017"] = preprocess_dataset_to_npy(
    "brats2017",
    DATASET_SPLITS["brats2017"]["all_patients"]
)

processed_patients["brats2018"] = preprocess_dataset_to_npy(
    "brats2018",
    DATASET_SPLITS["brats2018"]["all_patients"]
)

processed_patients["brats2019"] = preprocess_dataset_to_npy(
    "brats2019",
    DATASET_SPLITS["brats2019"]["all_patients"]
)
# Out:
# Preprocessing brats2017 → /home/zak/brats_project/processed/brats2017
# 100%|███████████████████████████████████████████████████████████████████████████████| 285/285 [00:00<00:00, 3755.41it/s]
# Skipping known bad patient: Brats17_2013_2_1
# Done. Processed patients: 284
# Preprocessing brats2018 → /home/zak/brats_project/processed/brats2018
# 100%|███████████████████████████████████████████████████████████████████████████████| 285/285 [00:00<00:00, 4097.50it/s]
# Done. Processed patients: 285
# Preprocessing brats2019 → /home/zak/brats_project/processed/brats2019
# 100%|███████████████████████████████████████████████████████████████████████████████| 335/335 [00:00<00:00, 3359.55it/s]
# Done. Processed patients: 335

# %%
# ============================================================
# Cell 5: Build slice indexes for each dataset separately
# ============================================================

def scan_slices(patient_list, skip_empty=True, min_tumor_pixels=10, stride=1):
    slice_index = []

    for patient in tqdm(patient_list):
        seg_path = find_file(patient, "seg")
        seg_img = nib.load(seg_path)

        depth = seg_img.shape[2]

        for s in range(0, depth, stride):
            seg_slice = np.asarray(seg_img.dataobj[:, :, s])

            if skip_empty:
                if np.sum(seg_slice > 0) < min_tumor_pixels:
                    continue

            slice_index.append((patient, s))

    return slice_index


DATASET_INDEXES = {}

for dataset_name, split_data in DATASET_SPLITS.items():
    print("\n" + "=" * 60)
    print("Scanning slices for:", dataset_name)
    print("=" * 60)

    train_patients = split_data["train_patients"]
    val_patients = split_data["val_patients"]
    test_patients = split_data["test_patients"]

    train_index = scan_slices(
        train_patients,
        skip_empty=True,
        min_tumor_pixels=10,
        stride=1
    )

    val_index = scan_slices(
        val_patients,
        skip_empty=True,
        min_tumor_pixels=10,
        stride=1
    )

    test_index = scan_slices(
        test_patients,
        skip_empty=True,
        min_tumor_pixels=10,
        stride=1
    )

    DATASET_INDEXES[dataset_name] = {
        "train_index": train_index,
        "val_index": val_index,
        "test_index": test_index
    }

    slice_table = pd.DataFrame({
        "Dataset": [dataset_name, dataset_name, dataset_name],
        "Set": ["Train", "Validation", "Test"],
        "Patients": [
            len(train_patients),
            len(val_patients),
            len(test_patients)
        ],
        "Tumor slices": [
            len(train_index),
            len(val_index),
            len(test_index)
        ]
    })

    display(slice_table)

    print("\nExample slice index:")
    print(train_index[0][0].split("/")[-1], "slice", train_index[0][1])
# Out:
# ============================================================
# Scanning slices for: brats2017
# ============================================================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 171/171 [00:03<00:00, 44.54it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 57/57 [00:01<00:00, 42.91it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 57/57 [00:01<00:00, 41.99it/s]
#      Dataset         Set  Patients  Tumor slices
# 0  brats2017       Train       171         11085
# 1  brats2017  Validation        57          3621
# 2  brats2017        Test        57          3710
# Example slice index:
# Brats17_CBICA_ATD_1 slice 71
#
# ============================================================
# Scanning slices for: brats2018
# ============================================================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 171/171 [00:04<00:00, 42.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 57/57 [00:01<00:00, 42.64it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 57/57 [00:01<00:00, 41.71it/s]
#      Dataset         Set  Patients  Tumor slices
# 0  brats2018       Train       171         11157
# 1  brats2018  Validation        57          3587
# 2  brats2018        Test        57          3672
# Example slice index:
# Brats18_CBICA_ATD_1 slice 71
#
# ============================================================
# Scanning slices for: brats2019
# ============================================================
# 100%|█████████████████████████████████████████████████████████████████████████████████| 201/201 [00:04<00:00, 40.83it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 67/67 [00:01<00:00, 40.91it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 67/67 [00:01<00:00, 39.52it/s]
#      Dataset         Set  Patients  Tumor slices
# 0  brats2019       Train       201         12912
# 1  brats2019  Validation        67          4339
# 2  brats2019        Test        67          4334
# Example slice index:
# BraTS19_069 slice 33

# %%
# ============================================================
# Cell 6: Build a simple batch generator
# ============================================================

from tensorflow.keras.utils import Sequence

class BraTSSliceGenerator(Sequence):
    def __init__(self, slice_index, batch_size=2, shuffle=True, augment=False):
        self.slice_index = list(slice_index)
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.augment = augment
        self.rng = np.random.default_rng(SEED)

        # Group slices by patient so we do not keep loading random patients all the time
        self.patient_slices = {}

        for patient, slice_id in self.slice_index:
            if patient not in self.patient_slices:
                self.patient_slices[patient] = []
            self.patient_slices[patient].append(slice_id)

        # Small cache: keeps the last loaded patient volume
        self.cached_patient = None
        self.cached_data = None

        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.pairs) / self.batch_size))

    def on_epoch_end(self):
        patients = list(self.patient_slices.keys())

        if self.shuffle:
            self.rng.shuffle(patients)

        pairs = []

        for patient in patients:
            slices = self.patient_slices[patient].copy()

            if self.shuffle:
                self.rng.shuffle(slices)

            for slice_id in slices:
                pairs.append((patient, slice_id))

        self.pairs = pairs

    def load_cached_patient(self, patient):
        # If this patient is already loaded, reuse it
        if self.cached_patient == patient:
            return self.cached_data

        # Otherwise load a new patient volume
        self.cached_patient = patient
        self.cached_data = load_patient_volume(patient)

        return self.cached_data

    def augment_sample(self, X, y):
        # Structural augmentation enhancement:
        # 1) spatial flips
        # 2) 90-degree rotations
        # 3) Gaussian noise regularization only on non-background MRI voxels
        # The same spatial transform is applied to image and mask together.

        if self.rng.random() < 0.5:
            X = np.flip(X, axis=1)
            y = np.flip(y, axis=1)

        if self.rng.random() < 0.5:
            X = np.flip(X, axis=0)
            y = np.flip(y, axis=0)

        k = self.rng.integers(0, 4)
        X = np.rot90(X, k, axes=(0, 1))
        y = np.rot90(y, k, axes=(0, 1))

        # Enhancement from the augmentation notebook:
        # add small Gaussian noise to the MRI channels only where signal exists.
        # This keeps the black background clean and regularizes the model.
        if self.rng.random() < 0.5:
            noise_std = self.rng.uniform(0.01, 0.05)
            noise = self.rng.normal(0, noise_std, X.shape).astype(np.float32)
            brain_mask = (X != 0).astype(np.float32)
            X = X + noise * brain_mask

        return X.copy(), y.copy()

    def __getitem__(self, idx):
        batch_pairs = self.pairs[
            idx * self.batch_size : (idx + 1) * self.batch_size
        ]

        X_batch = []
        y_batch = []

        for patient, slice_id in batch_pairs:
            x_vol, seg_vol = self.load_cached_patient(patient)

            X, y = make_slice_sample(x_vol, seg_vol, slice_id)

            if self.augment:
                X, y = self.augment_sample(X, y)

            X_batch.append(X)
            y_batch.append(y)

        return np.array(X_batch, dtype="float32"), np.array(y_batch, dtype="float32")


# Create the generators
train_gen = BraTSSliceGenerator(
    train_index,
    batch_size=BATCH_SIZE,
    shuffle=True,
    augment=True
)

val_gen = BraTSSliceGenerator(
    val_index,
    batch_size=BATCH_SIZE,
    shuffle=False,
    augment=False
)

test_gen = BraTSSliceGenerator(
    test_index,
    batch_size=BATCH_SIZE,
    shuffle=False,
    augment=False
)

print("Train batches:", len(train_gen))
print("Validation batches:", len(val_gen))
print("Test batches:", len(test_gen))

# Check one batch before training
X_batch, y_batch = train_gen[0]

print("\nOne training batch:")
print("X_batch shape:", X_batch.shape)
print("y_batch shape:", y_batch.shape)
print("X min/max:", X_batch.min(), X_batch.max())
print("Mask labels:", np.unique(np.argmax(y_batch, axis=-1)))
# Out:
# Train batches: 6456
# Validation batches: 2170
# Test batches: 2167
#
# One training batch:
# X_batch shape: (2, 128, 128, 4)
# y_batch shape: (2, 128, 128, 4)
# X min/max: -2.4114664 3.2329516
# Mask labels: [0 1 2 3]

# %%
# ============================================================
# Cell 7: Visual check from the generator
# ============================================================

# Take one batch from the training generator
X_batch, y_batch = train_gen[0]

# Show the first image in the batch
i = 0

image = X_batch[i]
mask = np.argmax(y_batch[i], axis=-1)

print("Image shape:", image.shape)
print("Mask shape:", mask.shape)
print("Mask labels:", np.unique(mask))

plt.figure(figsize=(14, 4))

plt.subplot(1, 4, 1)
plt.imshow(image[:, :, 0], cmap="gray")
plt.title("Flair")
plt.axis("off")

plt.subplot(1, 4, 2)
plt.imshow(image[:, :, 2], cmap="gray")
plt.title("T1ce")
plt.axis("off")

plt.subplot(1, 4, 3)
plt.imshow(mask)
plt.title("Segmentation mask")
plt.axis("off")

plt.subplot(1, 4, 4)
plt.imshow(image[:, :, 0], cmap="gray")
plt.imshow(mask, alpha=0.4)
plt.title("Mask overlay")
plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# Image shape: (128, 128, 4)
# Mask shape: (128, 128)
# Mask labels: [0 1 2 3]

# %%
# ============================================================
# Cell 8: Build the AGResU-Net model
# ============================================================

from tensorflow.keras import layers, Model

def conv_bn_prelu(x, filters, stride=1):
    # One basic convolution unit: BN -> PReLU -> 3x3 Conv
    x = layers.BatchNormalization()(x)
    x = layers.PReLU(shared_axes=[1, 2])(x)
    x = layers.Conv2D(
        filters,
        kernel_size=3,
        strides=stride,
        padding="same",
        kernel_initializer="glorot_uniform"
    )(x)
    return x


def residual_block(x, filters, stride=1):
    # Residual block: the input is added back to the output
    shortcut = x

    x = conv_bn_prelu(x, filters, stride=stride)
    x = conv_bn_prelu(x, filters, stride=1)

    # If shape changes, adjust the shortcut with 1x1 convolution
    if stride != 1 or shortcut.shape[-1] != filters:
        shortcut = layers.Conv2D(
            filters,
            kernel_size=1,
            strides=stride,
            padding="same",
            kernel_initializer="glorot_uniform"
        )(shortcut)

    return layers.Add()([x, shortcut])


def attention_gate(skip, gate, filters):
    # This gate decides how much of the skip connection should pass
    skip_part = layers.Conv2D(filters, 1, padding="same")(skip)
    gate_part = layers.Conv2D(filters, 1, padding="same")(gate)

    x = layers.Add()([skip_part, gate_part])
    x = layers.Activation("relu")(x)

    alpha = layers.Conv2D(filters, 1, padding="same", activation="sigmoid")(x)

    return layers.Multiply()([skip, alpha])


def decoder_block(x, skip, filters):
    # Upsample, apply attention to the skip connection, then combine
    x = layers.UpSampling2D(size=(2, 2), interpolation="bilinear")(x)

    skip = attention_gate(skip, x, filters)

    x = layers.Concatenate()([x, skip])
    x = layers.Conv2D(filters, 3, padding="same")(x)
    x = residual_block(x, filters)

    return x


def build_agresunet(input_shape=(128, 128, 4), num_classes=4):
    inputs = layers.Input(shape=input_shape)

    # Encoder
    e1 = residual_block(inputs, 64)          # 128x128
    e2 = residual_block(e1, 128, stride=2)   # 64x64
    e3 = residual_block(e2, 256, stride=2)   # 32x32

    # Bridge
    b = residual_block(e3, 512, stride=2)    # 16x16

    # Decoder
    d3 = decoder_block(b, e3, 256)           # 32x32
    d2 = decoder_block(d3, e2, 128)          # 64x64
    d1 = decoder_block(d2, e1, 64)           # 128x128

    # Final class probabilities
    outputs = layers.Conv2D(
        num_classes,
        kernel_size=1,
        activation="softmax",
        name="main_output"
    )(d1)

    return Model(inputs, outputs, name="AGResU_Net")


model = build_agresunet(
    input_shape=(PATCH_SIZE, PATCH_SIZE, 4),
    num_classes=NUM_CLASSES
)

print("Model name:", model.name)
print("Input shape:", model.input_shape)
print("Output shape:", model.output_shape)
print("Total parameters:", model.count_params())

# Test prediction on one batch
test_pred = model.predict(X_batch, verbose=0)

print("\nTest prediction shape:", test_pred.shape)
print("Prediction min/max:", test_pred.min(), test_pred.max())
print("Softmax sum min/max:", test_pred.sum(axis=-1).min(), test_pred.sum(axis=-1).max())
# Out:
# I0000 00:00:1778702305.367868     868 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9513 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 SUPER, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model name: AGResU_Net
# Input shape: (None, 128, 128, 4)
# Output shape: (None, 128, 128, 4)
# Total parameters: 9088472
# I0000 00:00:1778702307.125781    1163 service.cc:153] XLA service 0x78eac0042650 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778702307.125813    1163 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 4070 SUPER, Compute Capability 8.9 (Driver: 13.1.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.21.1)
# I0000 00:00:1778702307.150067    1163 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1778702307.321516    1163 cuda_dnn.cc:461] Loaded cuDNN version 92101
# E0000 00:00:1778702307.852092    1163 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Test prediction shape: (2, 128, 128, 4)
# Prediction min/max: 0.028202824 0.78001904
# Softmax sum min/max: 0.99999976 1.0000002
# I0000 00:00:1778702311.166412    1163 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %%
# ============================================================
# Cell 9: Losses, Dice metrics, and compile the model
# ============================================================

EPS = 1e-7

# Background is common, so it gets a smaller weight.
# Enhancing tumor is harder/smaller, so it gets a higher weight.
CLASS_WEIGHTS = tf.constant([0.2, 1.0, 1.0, 2.0], dtype=tf.float32)


def generalized_dice_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.clip_by_value(y_pred, EPS, 1.0 - EPS)

    # Sum over batch, height, and width
    axes = [0, 1, 2]

    class_sum = tf.reduce_sum(y_true, axis=axes)

    # If a class is missing in a batch, do not let it explode the loss
    weights = tf.where(
        class_sum > 0,
        1.0 / (tf.square(class_sum) + EPS),
        0.0
    )

    intersection = tf.reduce_sum(y_true * y_pred, axis=axes)
    total = tf.reduce_sum(y_true + y_pred, axis=axes)

    dice = (2.0 * tf.reduce_sum(weights * intersection) + EPS) / (
        tf.reduce_sum(weights * total) + EPS
    )

    return 1.0 - dice


def weighted_cross_entropy(y_true, y_pred):
    y_pred = tf.clip_by_value(y_pred, EPS, 1.0 - EPS)

    loss = -y_true * tf.math.log(y_pred) * CLASS_WEIGHTS

    return tf.reduce_mean(tf.reduce_sum(loss, axis=-1))


def combined_loss(y_true, y_pred):
    return generalized_dice_loss(y_true, y_pred) + weighted_cross_entropy(y_true, y_pred)


def dice_region(y_true, y_pred, classes):
    y_true = tf.cast(y_true, tf.float32)

    true_region = tf.reduce_sum(tf.gather(y_true, classes, axis=-1), axis=-1)
    pred_region = tf.reduce_sum(tf.gather(y_pred, classes, axis=-1), axis=-1)

    intersection = tf.reduce_sum(true_region * pred_region)
    total = tf.reduce_sum(true_region) + tf.reduce_sum(pred_region)

    return (2.0 * intersection + EPS) / (total + EPS)


def dice_wt(y_true, y_pred):
    return dice_region(y_true, y_pred, [1, 2, 3])


def dice_tc(y_true, y_pred):
    return dice_region(y_true, y_pred, [1, 3])


def dice_et(y_true, y_pred):
    return dice_region(y_true, y_pred, [3])


# SGD with momentum, following the paper direction.
# The paper learning rate is high, so we use a safer value for Colab stability.
LEARNING_RATE = 0.005
MOMENTUM = 0.97

optimizer = tf.keras.optimizers.SGD(
    learning_rate=LEARNING_RATE,
    momentum=MOMENTUM
)

model.compile(
    optimizer=optimizer,
    loss=combined_loss,
    metrics=[dice_wt, dice_tc, dice_et]
)

print("Model compiled successfully.")
print("Learning rate:", LEARNING_RATE)
print("Momentum:", MOMENTUM)
print("Class weights:", CLASS_WEIGHTS.numpy())

# Quick check before training
pred_check = model(X_batch, training=False)

print("\nLoss check:", float(combined_loss(y_batch, pred_check)))
print("Dice WT check:", float(dice_wt(y_batch, pred_check)))
print("Dice TC check:", float(dice_tc(y_batch, pred_check)))
print("Dice ET check:", float(dice_et(y_batch, pred_check)))
# Out:
# Model compiled successfully.
# Learning rate: 0.005
# Momentum: 0.97
# Class weights: [0.2 1.  1.  2. ]
#
# Loss check: 1.4023312330245972
# Dice WT check: 0.17062018811702728
# Dice TC check: 0.09589549154043198
# Dice ET check: 0.049777451902627945

# %%
# ============================================================
# Cell 10: Train from preprocessed .npy using generator
# ============================================================

from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, TerminateOnNaN
import time
import gc

EPOCHS = 40
BATCH_SIZE_FULL = 8
LEARNING_RATE_RUN = 0.003
MOMENTUM = 0.97
STEPS_PER_EPOCH = 1000
VAL_STEPS = 250


def one_hot_mask(mask, n_classes=NUM_CLASSES):
    out = np.zeros((*mask.shape, n_classes), dtype=np.float32)
    for c in range(n_classes):
        out[:, :, c] = (mask == c)
    return out


def tumor_center_crop_128(image_slice, mask_slice, size=128):
    h, w = mask_slice.shape

    tumor_pixels = np.argwhere(mask_slice > 0)

    if len(tumor_pixels) > 0:
        cy, cx = tumor_pixels.mean(axis=0).astype(int)
    else:
        cy, cx = h // 2, w // 2

    sh = max(0, min(cy - size // 2, h - size))
    sw = max(0, min(cx - size // 2, w - size))

    img_crop = image_slice[sh:sh + size, sw:sw + size, :]
    mask_crop = mask_slice[sh:sh + size, sw:sw + size]

    return img_crop.astype(np.float32), mask_crop.astype(np.uint8)


def tumor_aware_crop_128(image_slice, mask_slice, size=128, tumor_prob=0.85):
    h, w = mask_slice.shape
    tumor_pixels = np.argwhere(mask_slice > 0)

    if len(tumor_pixels) > 0 and random.random() < tumor_prob:
        cy, cx = tumor_pixels[random.randint(0, len(tumor_pixels) - 1)]

        sh = cy - size // 2 + random.randint(-20, 20)
        sw = cx - size // 2 + random.randint(-20, 20)

        sh = max(0, min(sh, h - size))
        sw = max(0, min(sw, w - size))
    else:
        sh = random.randint(0, max(h - size, 0))
        sw = random.randint(0, max(w - size, 0))

    img_crop = image_slice[sh:sh + size, sw:sw + size, :]
    mask_crop = mask_slice[sh:sh + size, sw:sw + size]

    return img_crop.astype(np.float32), mask_crop.astype(np.uint8)


class ProcessedBraTSGenerator(tf.keras.utils.Sequence):
    def __init__(self, processed_patient_dirs, batch_size=8, steps_per_epoch=1000,
                 augment=False, shuffle=True):
        self.patient_dirs = list(processed_patient_dirs)
        self.batch_size = batch_size
        self.steps_per_epoch = steps_per_epoch
        self.augment = augment
        self.shuffle = shuffle
        self.indexes = list(range(len(self.patient_dirs)))
        self.cache = {}
        self.max_cache_size = 4
        self.on_epoch_end()

    def __len__(self):
        return self.steps_per_epoch

    def on_epoch_end(self):
        if self.shuffle:
            random.shuffle(self.indexes)

    def load_processed_patient(self, patient_dir):
        patient_dir = Path(patient_dir)
        key = str(patient_dir)

        if key in self.cache:
            return self.cache[key]

        image = np.load(patient_dir / "image_4ch.npy", mmap_mode="r")
        mask = np.load(patient_dir / "mask.npy", mmap_mode="r")
        valid_slices = np.load(patient_dir / "valid_slices.npy")

        if len(self.cache) >= self.max_cache_size:
            self.cache.pop(next(iter(self.cache)))

        self.cache[key] = (image, mask, valid_slices)
        return image, mask, valid_slices

    def augment_sample(self, X, y):
        # Structural augmentation enhancement:
        # 1) spatial flips
        # 2) 90-degree rotations
        # 3) Gaussian noise regularization only on non-background MRI voxels
        # The same spatial transform is applied to image and mask together.

        if random.random() < 0.5:
            X = np.flip(X, axis=1)
            y = np.flip(y, axis=1)

        if random.random() < 0.5:
            X = np.flip(X, axis=0)
            y = np.flip(y, axis=0)

        k = random.randint(0, 3)
        X = np.rot90(X, k, axes=(0, 1))
        y = np.rot90(y, k, axes=(0, 1))

        # Enhancement from the augmentation notebook:
        # add small Gaussian noise to the MRI channels only where signal exists.
        # This keeps the black background clean and regularizes the model.
        if random.random() < 0.5:
            noise_std = random.uniform(0.01, 0.05)
            noise = np.random.normal(0, noise_std, X.shape).astype(np.float32)
            brain_mask = (X != 0).astype(np.float32)
            X = X + noise * brain_mask

        return X.copy(), y.copy()

    def __getitem__(self, idx):
        X_batch = []
        y_batch = []

        attempts = 0

        while len(X_batch) < self.batch_size and attempts < self.batch_size * 50:
            attempts += 1

            patient_dir = self.patient_dirs[random.choice(self.indexes)]

            try:
                img_vol, mask_vol, valid_slices = self.load_processed_patient(patient_dir)

                if len(valid_slices) > 0:
                    z = int(random.choice(valid_slices))
                else:
                    z = random.randint(0, mask_vol.shape[2] - 1)

                img_slice = np.asarray(img_vol[:, :, z, :], dtype=np.float32)
                mask_slice = np.asarray(mask_vol[:, :, z], dtype=np.uint8)

                if self.augment:
                    X, y_mask = tumor_aware_crop_128(img_slice, mask_slice)
                    X, y_mask = self.augment_sample(X, y_mask)
                else:
                    X, y_mask = tumor_center_crop_128(img_slice, mask_slice)

                y = one_hot_mask(y_mask)

                X_batch.append(X)
                y_batch.append(y)

            except Exception:
                continue

        if len(X_batch) == 0:
            X_batch = np.zeros((self.batch_size, PATCH_SIZE, PATCH_SIZE, 4), dtype=np.float32)
            y_batch = np.zeros((self.batch_size, PATCH_SIZE, PATCH_SIZE, NUM_CLASSES), dtype=np.float32)
            y_batch[..., 0] = 1.0
            return X_batch, y_batch

        while len(X_batch) < self.batch_size:
            X_batch.append(X_batch[-1])
            y_batch.append(y_batch[-1])

        return np.array(X_batch, dtype=np.float32), np.array(y_batch, dtype=np.float32)


def train_one_dataset(dataset_name):
    print("\n" + "=" * 80)
    print("STARTING DATASET:", dataset_name)
    print("=" * 80)

    train_patients = DATASET_SPLITS[dataset_name]["train_patients"]
    val_patients = DATASET_SPLITS[dataset_name]["val_patients"]

    processed_train = [
        PROCESSED_DIR / dataset_name / safe_patient_name(p)
        for p in train_patients
        if (PROCESSED_DIR / dataset_name / safe_patient_name(p)).exists()
    ]

    processed_val = [
        PROCESSED_DIR / dataset_name / safe_patient_name(p)
        for p in val_patients
        if (PROCESSED_DIR / dataset_name / safe_patient_name(p)).exists()
    ]

    print("Processed train patients:", len(processed_train))
    print("Processed validation patients:", len(processed_val))

    train_gen = ProcessedBraTSGenerator(
        processed_train,
        batch_size=BATCH_SIZE_FULL,
        steps_per_epoch=STEPS_PER_EPOCH,
        augment=True,
        shuffle=True
    )

    val_gen = ProcessedBraTSGenerator(
        processed_val,
        batch_size=BATCH_SIZE_FULL,
        steps_per_epoch=VAL_STEPS,
        augment=False,
        shuffle=False
    )

    tf.keras.backend.clear_session()
    gc.collect()

    random.seed(SEED)
    np.random.seed(SEED)
    tf.random.set_seed(SEED)

    model_full = build_agresunet(
        input_shape=(PATCH_SIZE, PATCH_SIZE, 4),
        num_classes=NUM_CLASSES
    )

    optimizer = tf.keras.optimizers.SGD(
        learning_rate=LEARNING_RATE_RUN,
        momentum=MOMENTUM
    )

    model_full.compile(
        optimizer=optimizer,
        loss=combined_loss,
        metrics=[dice_wt, dice_tc, dice_et]
    )

    checkpoint_path = OUTPUT_DIR / f"best_agresunet_{dataset_name}_40epochs_npy_generator.keras"
    final_model_path = OUTPUT_DIR / f"final_agresunet_{dataset_name}_40epochs_npy_generator.keras"
    log_path = OUTPUT_DIR / f"training_log_{dataset_name}_40epochs_npy_generator.csv"

    callbacks = [
        ModelCheckpoint(
            filepath=str(checkpoint_path),
            monitor="val_loss",
            save_best_only=True,
            mode="min",
            verbose=1
        ),

        CSVLogger(str(log_path)),

        ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.5,
            patience=5,
            min_lr=1e-5,
            verbose=1
        ),

        TerminateOnNaN()
    ]

    print("Train batches per epoch:", len(train_gen))
    print("Validation batches:", len(val_gen))
    print("Best model path:", checkpoint_path)

    start_time = time.time()

    history_full = model_full.fit(
        train_gen,
        validation_data=val_gen,
        epochs=EPOCHS,
        callbacks=callbacks,
        verbose=1
    )

    end_time = time.time()

    model_full.save(final_model_path)

    print("\nTraining finished for:", dataset_name)
    print("Training time in minutes:", round((end_time - start_time) / 60, 2))
    print("Best model saved to:", checkpoint_path)
    print("Final model saved to:", final_model_path)
    print("Training log saved to:", log_path)

    history_dict = history_full.history

    del model_full, train_gen, val_gen
    gc.collect()
    tf.keras.backend.clear_session()

    return history_dict

# %%
all_histories = {}

all_histories["brats2017"] = train_one_dataset("brats2017")
# Out:
# ================================================================================
# STARTING DATASET: brats2017
# ================================================================================
# Processed train patients: 171
# Processed validation patients: 57
# Train batches per epoch: 1000
# Validation batches: 250
# Best model path: /home/zak/brats_project/outputs/best_agresunet_brats2017_40epochs_npy_generator.keras
# /home/zak/tf-gpu/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/40
# I0000 00:00:1778702315.582189     868 generator_dataset_op.cc:213] Memory patch applied: M_TRIM_THRESHOLD=128 kb was set.
# I0000 00:00:1778702330.626436    1832 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'input_add_reduce_fusion_11', 364 bytes spill stores, 364 bytes spill loads
#
# I0000 00:00:1778702330.772995    1832 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'input_add_reduce_fusion_7', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1778702337.205546    1161 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'input_add_reduce_fusion_11', 364 bytes spill stores, 364 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_add_reduce_fusion_7', 4 bytes spill stores, 4 bytes spill loads
#  990/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - dice_et: 0.5782 - dice_tc: 0.4977 - dice_wt: 0.7487 - loss: 1.0851
# Epoch 1: val_loss improved from None to 0.59469, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2017_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 172s 150ms/step - dice_et: 0.6534 - dice_tc: 0.5807 - dice_wt: 0.7773 - loss: 0.8491 - val_dice_et: 0.7230 - val_dice_tc: 0.6446 - val_dice_wt: 0.8141 - val_loss: 0.5947 - learning_rate: 0.0030
# Epoch 2/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - dice_et: 0.7211 - dice_tc: 0.6810 - dice_wt: 0.8177 - loss: 0.5338
# Epoch 2: val_loss improved from 0.59469 to 0.56506, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2017_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 137s 136ms/step - dice_et: 0.7370 - dice_tc: 0.7062 - dice_wt: 0.8225 - loss: 0.4943 - val_dice_et: 0.7445 - val_dice_tc: 0.6950 - val_dice_wt: 0.8381 - val_loss: 0.5651 - learning_rate: 0.0030
# Epoch 3/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - dice_et: 0.7437 - dice_tc: 0.7200 - dice_wt: 0.8330 - loss: 0.4686
# Epoch 3: val_loss improved from 0.56506 to 0.47278, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2017_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 140s 139ms/step - dice_et: 0.7540 - dice_tc: 0.7385 - dice_wt: 0.8409 - loss: 0.4423 - val_dice_et: 0.7697 - val_dice_tc: 0.7255 - val_dice_wt: 0.8653 - val_loss: 0.4728 - learning_rate: 0.0030
# Epoch 4/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - dice_et: 0.7768 - dice_tc: 0.7667 - dice_wt: 0.8550 - loss: 0.4013
# Epoch 4: val_loss did not improve from 0.47278
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 140s 139ms/step - dice_et: 0.7716 - dice_tc: 0.7686 - dice_wt: 0.8564 - loss: 0.4063 - val_dice_et: 0.7726 - val_dice_tc: 0.7478 - val_dice_wt: 0.8541 - val_loss: 0.4853 - learning_rate: 0.0030
# Epoch 5/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - dice_et: 0.7882 - dice_tc: 0.7886 - dice_wt: 0.8604 - loss: 0.3862
# Epoch 5: val_loss improved from 0.47278 to 0.46739, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2017_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 139s 138ms/step - dice_et: 0.7797 - dice_tc: 0.7844 - dice_wt: 0.8633 - loss: 0.3923 - val_dice_et: 0.7955 - val_dice_tc: 0.7228 - val_dice_wt: 0.8473 - val_loss: 0.4674 - learning_rate: 0.0030
# Epoch 6/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - dice_et: 0.7933 - dice_tc: 0.7952 - dice_wt: 0.8636 - loss: 0.3662
# Epoch 6: val_loss improved from 0.46739 to 0.43091, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2017_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 139s 138ms/step - dice_et: 0.7928 - dice_tc: 0.8006 - dice_wt: 0.8684 - loss: 0.3648 - val_dice_et: 0.8035 - val_dice_tc: 0.7614 - val_dice_wt: 0.8478 - val_loss: 0.4309 - learning_rate: 0.0030
# Epoch 7/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - dice_et: 0.8042 - dice_tc: 0.8090 - dice_wt: 0.8655 - loss: 0.3570
# Epoch 7: val_loss did not improve from 0.43091
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 140s 140ms/step - dice_et: 0.7961 - dice_tc: 0.8035 - dice_wt: 0.8680 - loss: 0.3609 - val_dice_et: 0.7931 - val_dice_tc: 0.7638 - val_dice_wt: 0.8725 - val_loss: 0.4482 - learning_rate: 0.0030
# Epoch 8/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - dice_et: 0.7961 - dice_tc: 0.8170 - dice_wt: 0.8672 - loss: 0.3488
# Epoch 8: val_loss did not improve from 0.43091
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 140s 140ms/step - dice_et: 0.7933 - dice_tc: 0.8175 - dice_wt: 0.8709 - loss: 0.3477 - val_dice_et: 0.7986 - val_dice_tc: 0.7580 - val_dice_wt: 0.8706 - val_loss: 0.4675 - learning_rate: 0.0030
# Epoch 9/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - dice_et: 0.7966 - dice_tc: 0.8127 - dice_wt: 0.8743 - loss: 0.3474
# Epoch 9: val_loss did not improve from 0.43091
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 142s 141ms/step - dice_et: 0.7958 - dice_tc: 0.8176 - dice_wt: 0.8735 - loss: 0.3493 - val_dice_et: 0.7855 - val_dice_tc: 0.7684 - val_dice_wt: 0.8694 - val_loss: 0.4544 - learning_rate: 0.0030
# Epoch 10/40
#  982/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - dice_et: 0.7967 - dice_tc: 0.8255 - dice_wt: 0.8792 - loss: 0.3331
# Epoch 10: val_loss improved from 0.43091 to 0.42973, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2017_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 142s 142ms/step - dice_et: 0.8025 - dice_tc: 0.8312 - dice_wt: 0.8799 - loss: 0.3243 - val_dice_et: 0.8220 - val_dice_tc: 0.7739 - val_dice_wt: 0.8852 - val_loss: 0.4297 - learning_rate: 0.0030
# Epoch 11/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - dice_et: 0.8068 - dice_tc: 0.8276 - dice_wt: 0.8789 - loss: 0.3367
# Epoch 11: val_loss did not improve from 0.42973
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 143s 142ms/step - dice_et: 0.8070 - dice_tc: 0.8256 - dice_wt: 0.8792 - loss: 0.3341 - val_dice_et: 0.8170 - val_dice_tc: 0.7847 - val_dice_wt: 0.8703 - val_loss: 0.4393 - learning_rate: 0.0030
# Epoch 12/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - dice_et: 0.8042 - dice_tc: 0.8360 - dice_wt: 0.8819 - loss: 0.3244
# Epoch 12: val_loss improved from 0.42973 to 0.42271, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2017_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 144s 144ms/step - dice_et: 0.8067 - dice_tc: 0.8399 - dice_wt: 0.8823 - loss: 0.3193 - val_dice_et: 0.8115 - val_dice_tc: 0.7804 - val_dice_wt: 0.8719 - val_loss: 0.4227 - learning_rate: 0.0030
# Epoch 13/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - dice_et: 0.8133 - dice_tc: 0.8351 - dice_wt: 0.8811 - loss: 0.3127
# Epoch 13: val_loss did not improve from 0.42271
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 145s 144ms/step - dice_et: 0.8126 - dice_tc: 0.8317 - dice_wt: 0.8789 - loss: 0.3213 - val_dice_et: 0.8068 - val_dice_tc: 0.7648 - val_dice_wt: 0.8642 - val_loss: 0.4284 - learning_rate: 0.0030
# Epoch 14/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - dice_et: 0.8127 - dice_tc: 0.8472 - dice_wt: 0.8868 - loss: 0.3066
# Epoch 14: val_loss did not improve from 0.42271
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 145s 144ms/step - dice_et: 0.8154 - dice_tc: 0.8486 - dice_wt: 0.8878 - loss: 0.3056 - val_dice_et: 0.8161 - val_dice_tc: 0.7889 - val_dice_wt: 0.8680 - val_loss: 0.4378 - learning_rate: 0.0030
# Epoch 15/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - dice_et: 0.8184 - dice_tc: 0.8524 - dice_wt: 0.8869 - loss: 0.3018
# Epoch 15: val_loss did not improve from 0.42271
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 146s 146ms/step - dice_et: 0.8150 - dice_tc: 0.8469 - dice_wt: 0.8846 - loss: 0.3095 - val_dice_et: 0.8252 - val_dice_tc: 0.7781 - val_dice_wt: 0.8812 - val_loss: 0.4450 - learning_rate: 0.0030
# Epoch 16/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - dice_et: 0.8173 - dice_tc: 0.8536 - dice_wt: 0.8911 - loss: 0.3012
# Epoch 16: val_loss improved from 0.42271 to 0.41174, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2017_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 147s 147ms/step - dice_et: 0.8134 - dice_tc: 0.8511 - dice_wt: 0.8884 - loss: 0.3066 - val_dice_et: 0.8140 - val_dice_tc: 0.7885 - val_dice_wt: 0.8821 - val_loss: 0.4117 - learning_rate: 0.0030
# Epoch 17/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - dice_et: 0.8189 - dice_tc: 0.8578 - dice_wt: 0.8873 - loss: 0.2971
# Epoch 17: val_loss did not improve from 0.41174
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 147s 146ms/step - dice_et: 0.8203 - dice_tc: 0.8574 - dice_wt: 0.8897 - loss: 0.2922 - val_dice_et: 0.8243 - val_dice_tc: 0.7832 - val_dice_wt: 0.8817 - val_loss: 0.4424 - learning_rate: 0.0030
# Epoch 18/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - dice_et: 0.8143 - dice_tc: 0.8506 - dice_wt: 0.8856 - loss: 0.3059
# Epoch 18: val_loss did not improve from 0.41174
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 149s 148ms/step - dice_et: 0.8212 - dice_tc: 0.8555 - dice_wt: 0.8877 - loss: 0.2987 - val_dice_et: 0.8212 - val_dice_tc: 0.7635 - val_dice_wt: 0.8779 - val_loss: 0.4138 - learning_rate: 0.0030
# Epoch 19/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - dice_et: 0.8013 - dice_tc: 0.8470 - dice_wt: 0.8835 - loss: 0.3159
# Epoch 19: val_loss did not improve from 0.41174
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 148s 148ms/step - dice_et: 0.8053 - dice_tc: 0.8452 - dice_wt: 0.8833 - loss: 0.3130 - val_dice_et: 0.8181 - val_dice_tc: 0.7674 - val_dice_wt: 0.8788 - val_loss: 0.4165 - learning_rate: 0.0030
# Epoch 20/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - dice_et: 0.8222 - dice_tc: 0.8578 - dice_wt: 0.8876 - loss: 0.2925
# Epoch 20: val_loss did not improve from 0.41174
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 149s 148ms/step - dice_et: 0.8163 - dice_tc: 0.8516 - dice_wt: 0.8864 - loss: 0.3011 - val_dice_et: 0.7978 - val_dice_tc: 0.7670 - val_dice_wt: 0.8782 - val_loss: 0.4701 - learning_rate: 0.0030
# Epoch 21/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - dice_et: 0.8225 - dice_tc: 0.8590 - dice_wt: 0.8916 - loss: 0.2891
# Epoch 21: val_loss did not improve from 0.41174
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.001500000013038516.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 150s 150ms/step - dice_et: 0.8239 - dice_tc: 0.8599 - dice_wt: 0.8919 - loss: 0.2879 - val_dice_et: 0.8130 - val_dice_tc: 0.7493 - val_dice_wt: 0.8816 - val_loss: 0.4492 - learning_rate: 0.0030
# Epoch 22/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - dice_et: 0.8318 - dice_tc: 0.8658 - dice_wt: 0.8905 - loss: 0.2751
# Epoch 22: val_loss did not improve from 0.41174
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 151s 150ms/step - dice_et: 0.8353 - dice_tc: 0.8672 - dice_wt: 0.8931 - loss: 0.2696 - val_dice_et: 0.8214 - val_dice_tc: 0.7906 - val_dice_wt: 0.8837 - val_loss: 0.4188 - learning_rate: 0.0015
# Epoch 23/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - dice_et: 0.8358 - dice_tc: 0.8784 - dice_wt: 0.8985 - loss: 0.2570
# Epoch 23: val_loss did not improve from 0.41174
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 149s 148ms/step - dice_et: 0.8379 - dice_tc: 0.8782 - dice_wt: 0.8989 - loss: 0.2566 - val_dice_et: 0.8230 - val_dice_tc: 0.7787 - val_dice_wt: 0.8869 - val_loss: 0.4222 - learning_rate: 0.0015
# Epoch 24/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - dice_et: 0.8382 - dice_tc: 0.8755 - dice_wt: 0.8977 - loss: 0.2615
# Epoch 24: val_loss did not improve from 0.41174
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 153s 153ms/step - dice_et: 0.8370 - dice_tc: 0.8778 - dice_wt: 0.8983 - loss: 0.2620 - val_dice_et: 0.8204 - val_dice_tc: 0.7756 - val_dice_wt: 0.8857 - val_loss: 0.4152 - learning_rate: 0.0015
# Epoch 25/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - dice_et: 0.8442 - dice_tc: 0.8766 - dice_wt: 0.8980 - loss: 0.2521
# Epoch 25: val_loss did not improve from 0.41174
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 150s 149ms/step - dice_et: 0.8365 - dice_tc: 0.8770 - dice_wt: 0.8989 - loss: 0.2565 - val_dice_et: 0.8229 - val_dice_tc: 0.7792 - val_dice_wt: 0.8828 - val_loss: 0.4269 - learning_rate: 0.0015
# Epoch 26/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - dice_et: 0.8389 - dice_tc: 0.8863 - dice_wt: 0.8993 - loss: 0.2524
# Epoch 26: val_loss did not improve from 0.41174
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.000750000006519258.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 147s 147ms/step - dice_et: 0.8387 - dice_tc: 0.8863 - dice_wt: 0.8993 - loss: 0.2510 - val_dice_et: 0.8200 - val_dice_tc: 0.7821 - val_dice_wt: 0.8892 - val_loss: 0.4180 - learning_rate: 0.0015
# Epoch 27/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - dice_et: 0.8391 - dice_tc: 0.8819 - dice_wt: 0.9022 - loss: 0.2502
# Epoch 27: val_loss did not improve from 0.41174
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 149s 149ms/step - dice_et: 0.8425 - dice_tc: 0.8859 - dice_wt: 0.9030 - loss: 0.2470 - val_dice_et: 0.8226 - val_dice_tc: 0.7588 - val_dice_wt: 0.8813 - val_loss: 0.4379 - learning_rate: 7.5000e-04
# Epoch 28/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - dice_et: 0.8511 - dice_tc: 0.8923 - dice_wt: 0.9037 - loss: 0.2354
# Epoch 28: val_loss did not improve from 0.41174
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 146s 145ms/step - dice_et: 0.8503 - dice_tc: 0.8930 - dice_wt: 0.9027 - loss: 0.2387 - val_dice_et: 0.8117 - val_dice_tc: 0.7538 - val_dice_wt: 0.8829 - val_loss: 0.4625 - learning_rate: 7.5000e-04
# Epoch 29/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - dice_et: 0.8477 - dice_tc: 0.8900 - dice_wt: 0.9020 - loss: 0.2385
# Epoch 29: val_loss did not improve from 0.41174
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 150s 150ms/step - dice_et: 0.8477 - dice_tc: 0.8911 - dice_wt: 0.9031 - loss: 0.2386 - val_dice_et: 0.8167 - val_dice_tc: 0.7931 - val_dice_wt: 0.8771 - val_loss: 0.4135 - learning_rate: 7.5000e-04
# Epoch 30/40
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - dice_et: 0.8495 - dice_tc: 0.8892 - dice_wt: 0.9046 - loss: 0.2361
# Epoch 30: val_loss improved from 0.41174 to 0.41086, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2017_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 150s 149ms/step - dice_et: 0.8495 - dice_tc: 0.8886 - dice_wt: 0.9035 - loss: 0.2381 - val_dice_et: 0.8217 - val_dice_tc: 0.7930 - val_dice_wt: 0.8875 - val_loss: 0.4109 - learning_rate: 7.5000e-04
# Epoch 31/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - dice_et: 0.8582 - dice_tc: 0.8938 - dice_wt: 0.9057 - loss: 0.2294
# Epoch 31: val_loss did not improve from 0.41086
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 151s 151ms/step - dice_et: 0.8537 - dice_tc: 0.8920 - dice_wt: 0.9050 - loss: 0.2342 - val_dice_et: 0.8166 - val_dice_tc: 0.7755 - val_dice_wt: 0.8841 - val_loss: 0.4183 - learning_rate: 7.5000e-04
# Epoch 32/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - dice_et: 0.8561 - dice_tc: 0.8960 - dice_wt: 0.9048 - loss: 0.2317
# Epoch 32: val_loss did not improve from 0.41086
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 152s 152ms/step - dice_et: 0.8554 - dice_tc: 0.8941 - dice_wt: 0.9047 - loss: 0.2298 - val_dice_et: 0.8229 - val_dice_tc: 0.7804 - val_dice_wt: 0.8886 - val_loss: 0.4123 - learning_rate: 7.5000e-04
# Epoch 33/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - dice_et: 0.8509 - dice_tc: 0.8922 - dice_wt: 0.9022 - loss: 0.2369
# Epoch 33: val_loss did not improve from 0.41086
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 154s 153ms/step - dice_et: 0.8513 - dice_tc: 0.8892 - dice_wt: 0.9013 - loss: 0.2373 - val_dice_et: 0.8150 - val_dice_tc: 0.7893 - val_dice_wt: 0.8879 - val_loss: 0.4258 - learning_rate: 7.5000e-04
# Epoch 34/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - dice_et: 0.8527 - dice_tc: 0.8960 - dice_wt: 0.9048 - loss: 0.2325
# Epoch 34: val_loss did not improve from 0.41086
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 153s 153ms/step - dice_et: 0.8538 - dice_tc: 0.8939 - dice_wt: 0.9044 - loss: 0.2299 - val_dice_et: 0.8240 - val_dice_tc: 0.7761 - val_dice_wt: 0.8827 - val_loss: 0.4162 - learning_rate: 7.5000e-04
# Epoch 35/40
#  998/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - dice_et: 0.8597 - dice_tc: 0.8970 - dice_wt: 0.9078 - loss: 0.2220
# Epoch 35: val_loss did not improve from 0.41086
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.000375000003259629.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 151s 151ms/step - dice_et: 0.8585 - dice_tc: 0.8977 - dice_wt: 0.9073 - loss: 0.2258 - val_dice_et: 0.8253 - val_dice_tc: 0.7890 - val_dice_wt: 0.8862 - val_loss: 0.4200 - learning_rate: 7.5000e-04
# Epoch 36/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - dice_et: 0.8605 - dice_tc: 0.8995 - dice_wt: 0.9063 - loss: 0.2234
# Epoch 36: val_loss improved from 0.41086 to 0.40779, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2017_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 154s 154ms/step - dice_et: 0.8617 - dice_tc: 0.9012 - dice_wt: 0.9068 - loss: 0.2180 - val_dice_et: 0.8296 - val_dice_tc: 0.7908 - val_dice_wt: 0.8859 - val_loss: 0.4078 - learning_rate: 3.7500e-04
# Epoch 37/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - dice_et: 0.8531 - dice_tc: 0.8992 - dice_wt: 0.9056 - loss: 0.2246
# Epoch 37: val_loss improved from 0.40779 to 0.39843, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2017_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 155s 154ms/step - dice_et: 0.8583 - dice_tc: 0.9012 - dice_wt: 0.9059 - loss: 0.2217 - val_dice_et: 0.8332 - val_dice_tc: 0.7913 - val_dice_wt: 0.8876 - val_loss: 0.3984 - learning_rate: 3.7500e-04
# Epoch 38/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - dice_et: 0.8630 - dice_tc: 0.8969 - dice_wt: 0.9075 - loss: 0.2176
# Epoch 38: val_loss did not improve from 0.39843
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 155s 155ms/step - dice_et: 0.8630 - dice_tc: 0.8995 - dice_wt: 0.9075 - loss: 0.2167 - val_dice_et: 0.8221 - val_dice_tc: 0.7804 - val_dice_wt: 0.8844 - val_loss: 0.4329 - learning_rate: 3.7500e-04
# Epoch 39/40
#  995/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - dice_et: 0.8596 - dice_tc: 0.9015 - dice_wt: 0.9090 - loss: 0.2182
# Epoch 39: val_loss did not improve from 0.39843
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 155s 154ms/step - dice_et: 0.8618 - dice_tc: 0.9031 - dice_wt: 0.9092 - loss: 0.2146 - val_dice_et: 0.8193 - val_dice_tc: 0.7759 - val_dice_wt: 0.8903 - val_loss: 0.4299 - learning_rate: 3.7500e-04
# Epoch 40/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - dice_et: 0.8659 - dice_tc: 0.9040 - dice_wt: 0.9082 - loss: 0.2084
# Epoch 40: val_loss did not improve from 0.39843
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 156s 156ms/step - dice_et: 0.8620 - dice_tc: 0.9021 - dice_wt: 0.9072 - loss: 0.2130 - val_dice_et: 0.8259 - val_dice_tc: 0.7702 - val_dice_wt: 0.8846 - val_loss: 0.4372 - learning_rate: 3.7500e-04
#
# Training finished for: brats2017
# Training time in minutes: 98.75
# Best model saved to: /home/zak/brats_project/outputs/best_agresunet_brats2017_40epochs_npy_generator.keras
# Final model saved to: /home/zak/brats_project/outputs/final_agresunet_brats2017_40epochs_npy_generator.keras
# Training log saved to: /home/zak/brats_project/outputs/training_log_brats2017_40epochs_npy_generator.csv

# %%
all_histories["brats2018"] = train_one_dataset("brats2018")
# Out:
# ================================================================================
# STARTING DATASET: brats2018
# ================================================================================
# Processed train patients: 171
# Processed validation patients: 57
# Train batches per epoch: 1000
# Validation batches: 250
# Best model path: /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# Epoch 1/40
# I0000 00:00:1778708259.408729    1163 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'input_add_reduce_fusion_11', 364 bytes spill stores, 364 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_add_reduce_fusion_7', 4 bytes spill stores, 4 bytes spill loads
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - dice_et: 0.0675 - dice_tc: 0.0670 - dice_wt: 0.7386 - loss: 1.7775
# Epoch 1: val_loss improved from None to 1.69122, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 177s 167ms/step - dice_et: 0.0170 - dice_tc: 0.0167 - dice_wt: 0.7795 - loss: 1.8085 - val_dice_et: 0.0040 - val_dice_tc: 3.2441e-11 - val_dice_wt: 0.8508 - val_loss: 1.6912 - learning_rate: 0.0030
# Epoch 2/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - dice_et: 0.0020 - dice_tc: 2.7209e-11 - dice_wt: 0.8193 - loss: 1.7780
# Epoch 2: val_loss improved from 1.69122 to 1.68248, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 155s 154ms/step - dice_et: 0.0040 - dice_tc: 3.0799e-11 - dice_wt: 0.8242 - loss: 1.7632 - val_dice_et: 0.0079 - val_dice_tc: 4.3229e-10 - val_dice_wt: 0.8081 - val_loss: 1.6825 - learning_rate: 0.0030
# Epoch 3/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - dice_et: 5.2995e-05 - dice_tc: 0.0525 - dice_wt: 0.8078 - loss: 1.8132
# Epoch 3: val_loss did not improve from 1.68248
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 156s 156ms/step - dice_et: 3.8389e-05 - dice_tc: 0.1544 - dice_wt: 0.8049 - loss: 1.7674 - val_dice_et: 0.0021 - val_dice_tc: 0.5211 - val_dice_wt: 0.7957 - val_loss: 1.7286 - learning_rate: 0.0030
# Epoch 4/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - dice_et: 0.0247 - dice_tc: 0.6103 - dice_wt: 0.8174 - loss: 1.5261
# Epoch 4: val_loss improved from 1.68248 to 0.99966, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 163s 163ms/step - dice_et: 0.1694 - dice_tc: 0.6001 - dice_wt: 0.8228 - loss: 1.4291 - val_dice_et: 0.7142 - val_dice_tc: 0.5901 - val_dice_wt: 0.8398 - val_loss: 0.9997 - learning_rate: 0.0030
# Epoch 5/40
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - dice_et: 0.6974 - dice_tc: 0.5818 - dice_wt: 0.8239 - loss: 1.0520
# Epoch 5: val_loss improved from 0.99966 to 0.90991, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 153s 152ms/step - dice_et: 0.6976 - dice_tc: 0.6291 - dice_wt: 0.8345 - loss: 0.9972 - val_dice_et: 0.7162 - val_dice_tc: 0.6412 - val_dice_wt: 0.8288 - val_loss: 0.9099 - learning_rate: 0.0030
# Epoch 6/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - dice_et: 0.7279 - dice_tc: 0.7248 - dice_wt: 0.8484 - loss: 0.8447
# Epoch 6: val_loss improved from 0.90991 to 0.73796, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 158s 158ms/step - dice_et: 0.7362 - dice_tc: 0.7335 - dice_wt: 0.8543 - loss: 0.8144 - val_dice_et: 0.7635 - val_dice_tc: 0.7336 - val_dice_wt: 0.8445 - val_loss: 0.7380 - learning_rate: 0.0030
# Epoch 7/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - dice_et: 0.7660 - dice_tc: 0.7609 - dice_wt: 0.8621 - loss: 0.7343
# Epoch 7: val_loss improved from 0.73796 to 0.57521, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 158s 158ms/step - dice_et: 0.7677 - dice_tc: 0.7669 - dice_wt: 0.8592 - loss: 0.7029 - val_dice_et: 0.7605 - val_dice_tc: 0.7750 - val_dice_wt: 0.8738 - val_loss: 0.5752 - learning_rate: 0.0030
# Epoch 8/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - dice_et: 0.7770 - dice_tc: 0.7648 - dice_wt: 0.8529 - loss: 0.5146
# Epoch 8: val_loss improved from 0.57521 to 0.45826, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 152s 152ms/step - dice_et: 0.7718 - dice_tc: 0.7695 - dice_wt: 0.8543 - loss: 0.4689 - val_dice_et: 0.7581 - val_dice_tc: 0.7656 - val_dice_wt: 0.8559 - val_loss: 0.4583 - learning_rate: 0.0030
# Epoch 9/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - dice_et: 0.7884 - dice_tc: 0.7951 - dice_wt: 0.8623 - loss: 0.3914
# Epoch 9: val_loss improved from 0.45826 to 0.43857, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 153s 153ms/step - dice_et: 0.7909 - dice_tc: 0.7944 - dice_wt: 0.8620 - loss: 0.3893 - val_dice_et: 0.7975 - val_dice_tc: 0.7442 - val_dice_wt: 0.8807 - val_loss: 0.4386 - learning_rate: 0.0030
# Epoch 10/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - dice_et: 0.7946 - dice_tc: 0.7902 - dice_wt: 0.8637 - loss: 0.3918
# Epoch 10: val_loss improved from 0.43857 to 0.42291, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 155s 155ms/step - dice_et: 0.7936 - dice_tc: 0.7878 - dice_wt: 0.8607 - loss: 0.3916 - val_dice_et: 0.7806 - val_dice_tc: 0.7584 - val_dice_wt: 0.8197 - val_loss: 0.4229 - learning_rate: 0.0030
# Epoch 11/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - dice_et: 0.8007 - dice_tc: 0.8170 - dice_wt: 0.8733 - loss: 0.3547
# Epoch 11: val_loss improved from 0.42291 to 0.41642, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 158s 158ms/step - dice_et: 0.7978 - dice_tc: 0.8149 - dice_wt: 0.8699 - loss: 0.3633 - val_dice_et: 0.7925 - val_dice_tc: 0.7825 - val_dice_wt: 0.8685 - val_loss: 0.4164 - learning_rate: 0.0030
# Epoch 12/40
#  984/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - dice_et: 0.8080 - dice_tc: 0.8120 - dice_wt: 0.8704 - loss: 0.3580
# Epoch 12: val_loss improved from 0.41642 to 0.41552, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 153s 153ms/step - dice_et: 0.8111 - dice_tc: 0.8104 - dice_wt: 0.8721 - loss: 0.3513 - val_dice_et: 0.8009 - val_dice_tc: 0.7432 - val_dice_wt: 0.8549 - val_loss: 0.4155 - learning_rate: 0.0030
# Epoch 13/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - dice_et: 0.8015 - dice_tc: 0.8131 - dice_wt: 0.8729 - loss: 0.3527
# Epoch 13: val_loss improved from 0.41552 to 0.40589, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 156s 156ms/step - dice_et: 0.8068 - dice_tc: 0.8187 - dice_wt: 0.8741 - loss: 0.3432 - val_dice_et: 0.7992 - val_dice_tc: 0.7715 - val_dice_wt: 0.8635 - val_loss: 0.4059 - learning_rate: 0.0030
# Epoch 14/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - dice_et: 0.8123 - dice_tc: 0.8316 - dice_wt: 0.8784 - loss: 0.3424
# Epoch 14: val_loss improved from 0.40589 to 0.39042, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 161s 160ms/step - dice_et: 0.8072 - dice_tc: 0.8210 - dice_wt: 0.8758 - loss: 0.3516 - val_dice_et: 0.7979 - val_dice_tc: 0.7810 - val_dice_wt: 0.8588 - val_loss: 0.3904 - learning_rate: 0.0030
# Epoch 15/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - dice_et: 0.8132 - dice_tc: 0.8184 - dice_wt: 0.8748 - loss: 0.3413
# Epoch 15: val_loss improved from 0.39042 to 0.37771, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 156s 156ms/step - dice_et: 0.8135 - dice_tc: 0.8186 - dice_wt: 0.8762 - loss: 0.3392 - val_dice_et: 0.8192 - val_dice_tc: 0.7883 - val_dice_wt: 0.8694 - val_loss: 0.3777 - learning_rate: 0.0030
# Epoch 16/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - dice_et: 0.8083 - dice_tc: 0.8243 - dice_wt: 0.8731 - loss: 0.3389
# Epoch 16: val_loss improved from 0.37771 to 0.36669, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 158s 158ms/step - dice_et: 0.8113 - dice_tc: 0.8318 - dice_wt: 0.8796 - loss: 0.3335 - val_dice_et: 0.8227 - val_dice_tc: 0.7857 - val_dice_wt: 0.8802 - val_loss: 0.3667 - learning_rate: 0.0030
# Epoch 17/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - dice_et: 0.8166 - dice_tc: 0.8376 - dice_wt: 0.8834 - loss: 0.3222
# Epoch 17: val_loss did not improve from 0.36669
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 157s 156ms/step - dice_et: 0.8210 - dice_tc: 0.8408 - dice_wt: 0.8840 - loss: 0.3179 - val_dice_et: 0.8013 - val_dice_tc: 0.7897 - val_dice_wt: 0.8806 - val_loss: 0.3906 - learning_rate: 0.0030
# Epoch 18/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - dice_et: 0.8200 - dice_tc: 0.8356 - dice_wt: 0.8838 - loss: 0.3168
# Epoch 18: val_loss did not improve from 0.36669
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 157s 157ms/step - dice_et: 0.8213 - dice_tc: 0.8339 - dice_wt: 0.8817 - loss: 0.3226 - val_dice_et: 0.8152 - val_dice_tc: 0.7908 - val_dice_wt: 0.8733 - val_loss: 0.3668 - learning_rate: 0.0030
# Epoch 19/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - dice_et: 0.8207 - dice_tc: 0.8361 - dice_wt: 0.8824 - loss: 0.3222
# Epoch 19: val_loss did not improve from 0.36669
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 155s 155ms/step - dice_et: 0.8179 - dice_tc: 0.8347 - dice_wt: 0.8831 - loss: 0.3248 - val_dice_et: 0.8138 - val_dice_tc: 0.7703 - val_dice_wt: 0.8439 - val_loss: 0.3946 - learning_rate: 0.0030
# Epoch 20/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - dice_et: 0.8242 - dice_tc: 0.8351 - dice_wt: 0.8830 - loss: 0.3197
# Epoch 20: val_loss did not improve from 0.36669
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 158s 158ms/step - dice_et: 0.8171 - dice_tc: 0.8328 - dice_wt: 0.8840 - loss: 0.3231 - val_dice_et: 0.8181 - val_dice_tc: 0.7836 - val_dice_wt: 0.8638 - val_loss: 0.3896 - learning_rate: 0.0030
# Epoch 21/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - dice_et: 0.8236 - dice_tc: 0.8341 - dice_wt: 0.8826 - loss: 0.3175
# Epoch 21: val_loss did not improve from 0.36669
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.001500000013038516.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 151s 150ms/step - dice_et: 0.8185 - dice_tc: 0.8401 - dice_wt: 0.8826 - loss: 0.3173 - val_dice_et: 0.7979 - val_dice_tc: 0.7839 - val_dice_wt: 0.8817 - val_loss: 0.3976 - learning_rate: 0.0030
# Epoch 22/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - dice_et: 0.8241 - dice_tc: 0.8576 - dice_wt: 0.8872 - loss: 0.3039
# Epoch 22: val_loss did not improve from 0.36669
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 157s 157ms/step - dice_et: 0.8328 - dice_tc: 0.8573 - dice_wt: 0.8892 - loss: 0.2919 - val_dice_et: 0.8219 - val_dice_tc: 0.7894 - val_dice_wt: 0.8782 - val_loss: 0.3768 - learning_rate: 0.0015
# Epoch 23/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - dice_et: 0.8398 - dice_tc: 0.8634 - dice_wt: 0.8945 - loss: 0.2782
# Epoch 23: val_loss improved from 0.36669 to 0.34215, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 155s 154ms/step - dice_et: 0.8365 - dice_tc: 0.8632 - dice_wt: 0.8939 - loss: 0.2813 - val_dice_et: 0.8223 - val_dice_tc: 0.8095 - val_dice_wt: 0.8863 - val_loss: 0.3421 - learning_rate: 0.0015
# Epoch 24/40
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - dice_et: 0.8364 - dice_tc: 0.8664 - dice_wt: 0.8951 - loss: 0.2768
# Epoch 24: val_loss did not improve from 0.34215
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 156s 155ms/step - dice_et: 0.8396 - dice_tc: 0.8652 - dice_wt: 0.8943 - loss: 0.2761 - val_dice_et: 0.8103 - val_dice_tc: 0.7948 - val_dice_wt: 0.8815 - val_loss: 0.3841 - learning_rate: 0.0015
# Epoch 25/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - dice_et: 0.8416 - dice_tc: 0.8660 - dice_wt: 0.8929 - loss: 0.2806
# Epoch 25: val_loss did not improve from 0.34215
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 155s 155ms/step - dice_et: 0.8420 - dice_tc: 0.8667 - dice_wt: 0.8928 - loss: 0.2761 - val_dice_et: 0.8089 - val_dice_tc: 0.7883 - val_dice_wt: 0.8813 - val_loss: 0.3811 - learning_rate: 0.0015
# Epoch 26/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - dice_et: 0.8404 - dice_tc: 0.8715 - dice_wt: 0.8950 - loss: 0.2740
# Epoch 26: val_loss did not improve from 0.34215
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 154s 154ms/step - dice_et: 0.8395 - dice_tc: 0.8673 - dice_wt: 0.8941 - loss: 0.2744 - val_dice_et: 0.8273 - val_dice_tc: 0.8075 - val_dice_wt: 0.8822 - val_loss: 0.3618 - learning_rate: 0.0015
# Epoch 27/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - dice_et: 0.8510 - dice_tc: 0.8751 - dice_wt: 0.8992 - loss: 0.2607
# Epoch 27: val_loss did not improve from 0.34215
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 156s 156ms/step - dice_et: 0.8466 - dice_tc: 0.8734 - dice_wt: 0.8977 - loss: 0.2629 - val_dice_et: 0.8138 - val_dice_tc: 0.7990 - val_dice_wt: 0.8752 - val_loss: 0.3697 - learning_rate: 0.0015
# Epoch 28/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - dice_et: 0.8434 - dice_tc: 0.8726 - dice_wt: 0.8983 - loss: 0.2671
# Epoch 28: val_loss did not improve from 0.34215
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.000750000006519258.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 155s 155ms/step - dice_et: 0.8425 - dice_tc: 0.8738 - dice_wt: 0.8968 - loss: 0.2652 - val_dice_et: 0.8234 - val_dice_tc: 0.7912 - val_dice_wt: 0.8745 - val_loss: 0.3640 - learning_rate: 0.0015
# Epoch 29/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - dice_et: 0.8515 - dice_tc: 0.8783 - dice_wt: 0.8975 - loss: 0.2557
# Epoch 29: val_loss improved from 0.34215 to 0.34027, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 158s 157ms/step - dice_et: 0.8477 - dice_tc: 0.8739 - dice_wt: 0.8971 - loss: 0.2591 - val_dice_et: 0.8345 - val_dice_tc: 0.8021 - val_dice_wt: 0.8769 - val_loss: 0.3403 - learning_rate: 7.5000e-04
# Epoch 30/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - dice_et: 0.8538 - dice_tc: 0.8840 - dice_wt: 0.9006 - loss: 0.2472
# Epoch 30: val_loss did not improve from 0.34027
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 155s 155ms/step - dice_et: 0.8551 - dice_tc: 0.8849 - dice_wt: 0.9007 - loss: 0.2450 - val_dice_et: 0.8365 - val_dice_tc: 0.8056 - val_dice_wt: 0.8882 - val_loss: 0.3523 - learning_rate: 7.5000e-04
# Epoch 31/40
#  982/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - dice_et: 0.8604 - dice_tc: 0.8831 - dice_wt: 0.9010 - loss: 0.2429
# Epoch 31: val_loss did not improve from 0.34027
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 155s 154ms/step - dice_et: 0.8573 - dice_tc: 0.8839 - dice_wt: 0.9012 - loss: 0.2458 - val_dice_et: 0.8195 - val_dice_tc: 0.7911 - val_dice_wt: 0.8883 - val_loss: 0.3724 - learning_rate: 7.5000e-04
# Epoch 32/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - dice_et: 0.8587 - dice_tc: 0.8813 - dice_wt: 0.9003 - loss: 0.2456
# Epoch 32: val_loss did not improve from 0.34027
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 157s 157ms/step - dice_et: 0.8552 - dice_tc: 0.8825 - dice_wt: 0.8993 - loss: 0.2483 - val_dice_et: 0.8269 - val_dice_tc: 0.7927 - val_dice_wt: 0.8875 - val_loss: 0.3538 - learning_rate: 7.5000e-04
# Epoch 33/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - dice_et: 0.8523 - dice_tc: 0.8838 - dice_wt: 0.9005 - loss: 0.2464
# Epoch 33: val_loss did not improve from 0.34027
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 162s 161ms/step - dice_et: 0.8519 - dice_tc: 0.8853 - dice_wt: 0.9008 - loss: 0.2489 - val_dice_et: 0.8351 - val_dice_tc: 0.8102 - val_dice_wt: 0.9025 - val_loss: 0.3482 - learning_rate: 7.5000e-04
# Epoch 34/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - dice_et: 0.8551 - dice_tc: 0.8852 - dice_wt: 0.9004 - loss: 0.2455
# Epoch 34: val_loss did not improve from 0.34027
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.000375000003259629.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 159s 158ms/step - dice_et: 0.8588 - dice_tc: 0.8893 - dice_wt: 0.9027 - loss: 0.2388 - val_dice_et: 0.8283 - val_dice_tc: 0.8158 - val_dice_wt: 0.8711 - val_loss: 0.3527 - learning_rate: 7.5000e-04
# Epoch 35/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - dice_et: 0.8620 - dice_tc: 0.8922 - dice_wt: 0.9022 - loss: 0.2410
# Epoch 35: val_loss did not improve from 0.34027
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 156s 156ms/step - dice_et: 0.8591 - dice_tc: 0.8903 - dice_wt: 0.9026 - loss: 0.2389 - val_dice_et: 0.8112 - val_dice_tc: 0.8036 - val_dice_wt: 0.8843 - val_loss: 0.3679 - learning_rate: 3.7500e-04
# Epoch 36/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - dice_et: 0.8572 - dice_tc: 0.8918 - dice_wt: 0.9034 - loss: 0.2409
# Epoch 36: val_loss did not improve from 0.34027
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 155s 155ms/step - dice_et: 0.8564 - dice_tc: 0.8909 - dice_wt: 0.9032 - loss: 0.2400 - val_dice_et: 0.8300 - val_dice_tc: 0.8102 - val_dice_wt: 0.8826 - val_loss: 0.3448 - learning_rate: 3.7500e-04
# Epoch 37/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - dice_et: 0.8623 - dice_tc: 0.8941 - dice_wt: 0.9043 - loss: 0.2260
# Epoch 37: val_loss did not improve from 0.34027
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 155s 154ms/step - dice_et: 0.8605 - dice_tc: 0.8931 - dice_wt: 0.9034 - loss: 0.2309 - val_dice_et: 0.8362 - val_dice_tc: 0.8255 - val_dice_wt: 0.8934 - val_loss: 0.3461 - learning_rate: 3.7500e-04
# Epoch 38/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - dice_et: 0.8585 - dice_tc: 0.8923 - dice_wt: 0.9033 - loss: 0.2349
# Epoch 38: val_loss did not improve from 0.34027
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 158s 157ms/step - dice_et: 0.8576 - dice_tc: 0.8931 - dice_wt: 0.9041 - loss: 0.2349 - val_dice_et: 0.8279 - val_dice_tc: 0.8060 - val_dice_wt: 0.8880 - val_loss: 0.3573 - learning_rate: 3.7500e-04
# Epoch 39/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - dice_et: 0.8669 - dice_tc: 0.8972 - dice_wt: 0.9031 - loss: 0.2215
# Epoch 39: val_loss did not improve from 0.34027
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0001875000016298145.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 159s 159ms/step - dice_et: 0.8700 - dice_tc: 0.8980 - dice_wt: 0.9048 - loss: 0.2213 - val_dice_et: 0.8190 - val_dice_tc: 0.8124 - val_dice_wt: 0.8912 - val_loss: 0.3519 - learning_rate: 3.7500e-04
# Epoch 40/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - dice_et: 0.8588 - dice_tc: 0.8997 - dice_wt: 0.9078 - loss: 0.2282
# Epoch 40: val_loss did not improve from 0.34027
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 150s 150ms/step - dice_et: 0.8595 - dice_tc: 0.8971 - dice_wt: 0.9059 - loss: 0.2276 - val_dice_et: 0.8193 - val_dice_tc: 0.8199 - val_dice_wt: 0.8889 - val_loss: 0.3512 - learning_rate: 1.8750e-04
#
# Training finished for: brats2018
# Training time in minutes: 104.46
# Best model saved to: /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# Final model saved to: /home/zak/brats_project/outputs/final_agresunet_brats2018_40epochs_npy_generator.keras
# Training log saved to: /home/zak/brats_project/outputs/training_log_brats2018_40epochs_npy_generator.csv

# %%
all_histories["brats2019"] = train_one_dataset("brats2019")
# Out:
# ================================================================================
# STARTING DATASET: brats2019
# ================================================================================
# Processed train patients: 201
# Processed validation patients: 67
# Train batches per epoch: 1000
# Validation batches: 250
# Best model path: /home/zak/brats_project/outputs/best_agresunet_brats2019_40epochs_npy_generator.keras
# Epoch 1/40
# I0000 00:00:1778714538.324532    1163 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'input_add_reduce_fusion_11', 364 bytes spill stores, 364 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_add_reduce_fusion_7', 4 bytes spill stores, 4 bytes spill loads
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - dice_et: 0.6429 - dice_tc: 0.5381 - dice_wt: 0.7669 - loss: 1.0697
# Epoch 1: val_loss improved from None to 0.58083, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2019_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 227s 213ms/step - dice_et: 0.7090 - dice_tc: 0.6017 - dice_wt: 0.7975 - loss: 0.8395 - val_dice_et: 0.7454 - val_dice_tc: 0.6660 - val_dice_wt: 0.8010 - val_loss: 0.5808 - learning_rate: 0.0030
# Epoch 2/40
#  994/1000 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - dice_et: 0.7851 - dice_tc: 0.7322 - dice_wt: 0.8361 - loss: 0.4705
# Epoch 2: val_loss improved from 0.58083 to 0.47314, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2019_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 205s 204ms/step - dice_et: 0.7841 - dice_tc: 0.7416 - dice_wt: 0.8405 - loss: 0.4501 - val_dice_et: 0.7677 - val_dice_tc: 0.7294 - val_dice_wt: 0.7814 - val_loss: 0.4731 - learning_rate: 0.0030
# Epoch 3/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - dice_et: 0.7962 - dice_tc: 0.7574 - dice_wt: 0.8555 - loss: 0.4094
# Epoch 3: val_loss improved from 0.47314 to 0.43719, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2019_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 200s 199ms/step - dice_et: 0.8058 - dice_tc: 0.7663 - dice_wt: 0.8582 - loss: 0.4024 - val_dice_et: 0.7889 - val_dice_tc: 0.7490 - val_dice_wt: 0.8530 - val_loss: 0.4372 - learning_rate: 0.0030
# Epoch 4/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - dice_et: 0.8070 - dice_tc: 0.7610 - dice_wt: 0.8700 - loss: 0.4014
# Epoch 4: val_loss improved from 0.43719 to 0.42380, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2019_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 204s 204ms/step - dice_et: 0.8071 - dice_tc: 0.7745 - dice_wt: 0.8693 - loss: 0.3867 - val_dice_et: 0.7782 - val_dice_tc: 0.7826 - val_dice_wt: 0.8704 - val_loss: 0.4238 - learning_rate: 0.0030
# Epoch 5/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - dice_et: 0.8084 - dice_tc: 0.7901 - dice_wt: 0.8679 - loss: 0.3750
# Epoch 5: val_loss improved from 0.42380 to 0.38288, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2019_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 199s 199ms/step - dice_et: 0.8165 - dice_tc: 0.7929 - dice_wt: 0.8703 - loss: 0.3699 - val_dice_et: 0.8075 - val_dice_tc: 0.8049 - val_dice_wt: 0.8716 - val_loss: 0.3829 - learning_rate: 0.0030
# Epoch 6/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - dice_et: 0.8259 - dice_tc: 0.7988 - dice_wt: 0.8749 - loss: 0.3524
# Epoch 6: val_loss did not improve from 0.38288
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 209s 208ms/step - dice_et: 0.8231 - dice_tc: 0.7952 - dice_wt: 0.8738 - loss: 0.3615 - val_dice_et: 0.7787 - val_dice_tc: 0.7846 - val_dice_wt: 0.8584 - val_loss: 0.3949 - learning_rate: 0.0030
# Epoch 7/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - dice_et: 0.8245 - dice_tc: 0.8129 - dice_wt: 0.8781 - loss: 0.3428
# Epoch 7: val_loss improved from 0.38288 to 0.35996, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2019_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 202s 202ms/step - dice_et: 0.8292 - dice_tc: 0.8131 - dice_wt: 0.8810 - loss: 0.3380 - val_dice_et: 0.8205 - val_dice_tc: 0.8096 - val_dice_wt: 0.8760 - val_loss: 0.3600 - learning_rate: 0.0030
# Epoch 8/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - dice_et: 0.8332 - dice_tc: 0.8142 - dice_wt: 0.8832 - loss: 0.3274
# Epoch 8: val_loss did not improve from 0.35996
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 201s 201ms/step - dice_et: 0.8322 - dice_tc: 0.8112 - dice_wt: 0.8837 - loss: 0.3337 - val_dice_et: 0.7993 - val_dice_tc: 0.8073 - val_dice_wt: 0.8835 - val_loss: 0.3978 - learning_rate: 0.0030
# Epoch 9/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - dice_et: 0.8363 - dice_tc: 0.8197 - dice_wt: 0.8850 - loss: 0.3271
# Epoch 9: val_loss did not improve from 0.35996
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 201s 201ms/step - dice_et: 0.8346 - dice_tc: 0.8228 - dice_wt: 0.8855 - loss: 0.3300 - val_dice_et: 0.8164 - val_dice_tc: 0.8090 - val_dice_wt: 0.8855 - val_loss: 0.3625 - learning_rate: 0.0030
# Epoch 10/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - dice_et: 0.8393 - dice_tc: 0.8266 - dice_wt: 0.8878 - loss: 0.3198
# Epoch 10: val_loss did not improve from 0.35996
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 200s 200ms/step - dice_et: 0.8397 - dice_tc: 0.8306 - dice_wt: 0.8883 - loss: 0.3177 - val_dice_et: 0.8114 - val_dice_tc: 0.8289 - val_dice_wt: 0.8539 - val_loss: 0.3674 - learning_rate: 0.0030
# Epoch 11/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - dice_et: 0.8247 - dice_tc: 0.8230 - dice_wt: 0.8854 - loss: 0.3241
# Epoch 11: val_loss did not improve from 0.35996
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 204s 203ms/step - dice_et: 0.8291 - dice_tc: 0.8272 - dice_wt: 0.8879 - loss: 0.3187 - val_dice_et: 0.7897 - val_dice_tc: 0.8180 - val_dice_wt: 0.8775 - val_loss: 0.3650 - learning_rate: 0.0030
# Epoch 12/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - dice_et: 0.8400 - dice_tc: 0.8291 - dice_wt: 0.8882 - loss: 0.3080
# Epoch 12: val_loss did not improve from 0.35996
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.001500000013038516.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 202s 202ms/step - dice_et: 0.8383 - dice_tc: 0.8254 - dice_wt: 0.8866 - loss: 0.3200 - val_dice_et: 0.8014 - val_dice_tc: 0.8187 - val_dice_wt: 0.8817 - val_loss: 0.3989 - learning_rate: 0.0030
# Epoch 13/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - dice_et: 0.8468 - dice_tc: 0.8441 - dice_wt: 0.8910 - loss: 0.3008
# Epoch 13: val_loss improved from 0.35996 to 0.35722, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2019_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 203s 202ms/step - dice_et: 0.8476 - dice_tc: 0.8439 - dice_wt: 0.8946 - loss: 0.2966 - val_dice_et: 0.8118 - val_dice_tc: 0.8250 - val_dice_wt: 0.8805 - val_loss: 0.3572 - learning_rate: 0.0015
# Epoch 14/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - dice_et: 0.8396 - dice_tc: 0.8490 - dice_wt: 0.8954 - loss: 0.2904
# Epoch 14: val_loss improved from 0.35722 to 0.33270, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2019_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 201s 201ms/step - dice_et: 0.8436 - dice_tc: 0.8521 - dice_wt: 0.8968 - loss: 0.2867 - val_dice_et: 0.8253 - val_dice_tc: 0.8437 - val_dice_wt: 0.8822 - val_loss: 0.3327 - learning_rate: 0.0015
# Epoch 15/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - dice_et: 0.8529 - dice_tc: 0.8601 - dice_wt: 0.8994 - loss: 0.2735
# Epoch 15: val_loss did not improve from 0.33270
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 201s 201ms/step - dice_et: 0.8526 - dice_tc: 0.8604 - dice_wt: 0.9001 - loss: 0.2735 - val_dice_et: 0.8130 - val_dice_tc: 0.8432 - val_dice_wt: 0.8924 - val_loss: 0.3470 - learning_rate: 0.0015
# Epoch 16/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - dice_et: 0.8514 - dice_tc: 0.8590 - dice_wt: 0.8964 - loss: 0.2745
# Epoch 16: val_loss did not improve from 0.33270
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 197s 197ms/step - dice_et: 0.8511 - dice_tc: 0.8599 - dice_wt: 0.9000 - loss: 0.2750 - val_dice_et: 0.8132 - val_dice_tc: 0.8255 - val_dice_wt: 0.8800 - val_loss: 0.3539 - learning_rate: 0.0015
# Epoch 17/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - dice_et: 0.8515 - dice_tc: 0.8575 - dice_wt: 0.9001 - loss: 0.2774
# Epoch 17: val_loss did not improve from 0.33270
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 200s 200ms/step - dice_et: 0.8502 - dice_tc: 0.8539 - dice_wt: 0.8983 - loss: 0.2798 - val_dice_et: 0.8220 - val_dice_tc: 0.8284 - val_dice_wt: 0.8888 - val_loss: 0.3485 - learning_rate: 0.0015
# Epoch 18/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - dice_et: 0.8515 - dice_tc: 0.8663 - dice_wt: 0.9016 - loss: 0.2717
# Epoch 18: val_loss did not improve from 0.33270
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 198s 198ms/step - dice_et: 0.8520 - dice_tc: 0.8653 - dice_wt: 0.9004 - loss: 0.2711 - val_dice_et: 0.8186 - val_dice_tc: 0.8151 - val_dice_wt: 0.8858 - val_loss: 0.3882 - learning_rate: 0.0015
# Epoch 19/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - dice_et: 0.8581 - dice_tc: 0.8629 - dice_wt: 0.9028 - loss: 0.2732
# Epoch 19: val_loss did not improve from 0.33270
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.000750000006519258.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 199s 199ms/step - dice_et: 0.8590 - dice_tc: 0.8656 - dice_wt: 0.9027 - loss: 0.2690 - val_dice_et: 0.8149 - val_dice_tc: 0.8411 - val_dice_wt: 0.8908 - val_loss: 0.3609 - learning_rate: 0.0015
# Epoch 20/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - dice_et: 0.8548 - dice_tc: 0.8644 - dice_wt: 0.9029 - loss: 0.2684
# Epoch 20: val_loss did not improve from 0.33270
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 201s 200ms/step - dice_et: 0.8555 - dice_tc: 0.8681 - dice_wt: 0.9041 - loss: 0.2595 - val_dice_et: 0.8138 - val_dice_tc: 0.8405 - val_dice_wt: 0.8899 - val_loss: 0.3366 - learning_rate: 7.5000e-04
# Epoch 21/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - dice_et: 0.8593 - dice_tc: 0.8705 - dice_wt: 0.9050 - loss: 0.2595
# Epoch 21: val_loss improved from 0.33270 to 0.32623, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2019_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 203s 203ms/step - dice_et: 0.8588 - dice_tc: 0.8718 - dice_wt: 0.9045 - loss: 0.2585 - val_dice_et: 0.8152 - val_dice_tc: 0.8386 - val_dice_wt: 0.8851 - val_loss: 0.3262 - learning_rate: 7.5000e-04
# Epoch 22/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - dice_et: 0.8593 - dice_tc: 0.8789 - dice_wt: 0.9058 - loss: 0.2551
# Epoch 22: val_loss did not improve from 0.32623
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 200s 200ms/step - dice_et: 0.8574 - dice_tc: 0.8773 - dice_wt: 0.9053 - loss: 0.2565 - val_dice_et: 0.8208 - val_dice_tc: 0.8498 - val_dice_wt: 0.8899 - val_loss: 0.3309 - learning_rate: 7.5000e-04
# Epoch 23/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - dice_et: 0.8621 - dice_tc: 0.8761 - dice_wt: 0.9072 - loss: 0.2552
# Epoch 23: val_loss did not improve from 0.32623
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 197s 197ms/step - dice_et: 0.8634 - dice_tc: 0.8817 - dice_wt: 0.9070 - loss: 0.2503 - val_dice_et: 0.8156 - val_dice_tc: 0.8529 - val_dice_wt: 0.8851 - val_loss: 0.3379 - learning_rate: 7.5000e-04
# Epoch 24/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - dice_et: 0.8615 - dice_tc: 0.8770 - dice_wt: 0.9057 - loss: 0.2555
# Epoch 24: val_loss did not improve from 0.32623
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 204s 203ms/step - dice_et: 0.8603 - dice_tc: 0.8760 - dice_wt: 0.9040 - loss: 0.2556 - val_dice_et: 0.8053 - val_dice_tc: 0.8280 - val_dice_wt: 0.8818 - val_loss: 0.3546 - learning_rate: 7.5000e-04
# Epoch 25/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - dice_et: 0.8616 - dice_tc: 0.8820 - dice_wt: 0.9076 - loss: 0.2429
# Epoch 25: val_loss did not improve from 0.32623
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 201s 200ms/step - dice_et: 0.8620 - dice_tc: 0.8811 - dice_wt: 0.9067 - loss: 0.2464 - val_dice_et: 0.8245 - val_dice_tc: 0.8435 - val_dice_wt: 0.8889 - val_loss: 0.3327 - learning_rate: 7.5000e-04
# Epoch 26/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - dice_et: 0.8695 - dice_tc: 0.8840 - dice_wt: 0.9080 - loss: 0.2360
# Epoch 26: val_loss did not improve from 0.32623
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.000375000003259629.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 199s 199ms/step - dice_et: 0.8685 - dice_tc: 0.8860 - dice_wt: 0.9091 - loss: 0.2395 - val_dice_et: 0.8113 - val_dice_tc: 0.8324 - val_dice_wt: 0.8871 - val_loss: 0.3424 - learning_rate: 7.5000e-04
# Epoch 27/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - dice_et: 0.8751 - dice_tc: 0.8939 - dice_wt: 0.9103 - loss: 0.2234
# Epoch 27: val_loss did not improve from 0.32623
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 201s 201ms/step - dice_et: 0.8729 - dice_tc: 0.8932 - dice_wt: 0.9105 - loss: 0.2279 - val_dice_et: 0.8229 - val_dice_tc: 0.8490 - val_dice_wt: 0.8950 - val_loss: 0.3327 - learning_rate: 3.7500e-04
# Epoch 28/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - dice_et: 0.8685 - dice_tc: 0.8927 - dice_wt: 0.9112 - loss: 0.2369
# Epoch 28: val_loss did not improve from 0.32623
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 201s 201ms/step - dice_et: 0.8673 - dice_tc: 0.8926 - dice_wt: 0.9111 - loss: 0.2350 - val_dice_et: 0.8057 - val_dice_tc: 0.8408 - val_dice_wt: 0.8939 - val_loss: 0.3580 - learning_rate: 3.7500e-04
# Epoch 29/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - dice_et: 0.8706 - dice_tc: 0.8892 - dice_wt: 0.9109 - loss: 0.2294
# Epoch 29: val_loss did not improve from 0.32623
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 203s 203ms/step - dice_et: 0.8712 - dice_tc: 0.8921 - dice_wt: 0.9112 - loss: 0.2258 - val_dice_et: 0.8088 - val_dice_tc: 0.8274 - val_dice_wt: 0.8921 - val_loss: 0.3518 - learning_rate: 3.7500e-04
# Epoch 30/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - dice_et: 0.8727 - dice_tc: 0.8909 - dice_wt: 0.9108 - loss: 0.2325
# Epoch 30: val_loss did not improve from 0.32623
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 203s 202ms/step - dice_et: 0.8698 - dice_tc: 0.8921 - dice_wt: 0.9104 - loss: 0.2312 - val_dice_et: 0.8158 - val_dice_tc: 0.8619 - val_dice_wt: 0.8974 - val_loss: 0.3292 - learning_rate: 3.7500e-04
# Epoch 31/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - dice_et: 0.8729 - dice_tc: 0.8924 - dice_wt: 0.9087 - loss: 0.2311
# Epoch 31: val_loss did not improve from 0.32623
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0001875000016298145.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 201s 200ms/step - dice_et: 0.8726 - dice_tc: 0.8930 - dice_wt: 0.9097 - loss: 0.2319 - val_dice_et: 0.8221 - val_dice_tc: 0.8307 - val_dice_wt: 0.8873 - val_loss: 0.3393 - learning_rate: 3.7500e-04
# Epoch 32/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - dice_et: 0.8659 - dice_tc: 0.8919 - dice_wt: 0.9107 - loss: 0.2361
# Epoch 32: val_loss did not improve from 0.32623
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 201s 201ms/step - dice_et: 0.8679 - dice_tc: 0.8981 - dice_wt: 0.9114 - loss: 0.2282 - val_dice_et: 0.8223 - val_dice_tc: 0.8534 - val_dice_wt: 0.8932 - val_loss: 0.3348 - learning_rate: 1.8750e-04
# Epoch 33/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - dice_et: 0.8642 - dice_tc: 0.8984 - dice_wt: 0.9120 - loss: 0.2256
# Epoch 33: val_loss did not improve from 0.32623
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 198s 198ms/step - dice_et: 0.8696 - dice_tc: 0.8943 - dice_wt: 0.9106 - loss: 0.2249 - val_dice_et: 0.8210 - val_dice_tc: 0.8449 - val_dice_wt: 0.8970 - val_loss: 0.3441 - learning_rate: 1.8750e-04
# Epoch 34/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - dice_et: 0.8692 - dice_tc: 0.8988 - dice_wt: 0.9141 - loss: 0.2205
# Epoch 34: val_loss did not improve from 0.32623
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 201s 201ms/step - dice_et: 0.8706 - dice_tc: 0.8968 - dice_wt: 0.9128 - loss: 0.2206 - val_dice_et: 0.8262 - val_dice_tc: 0.8476 - val_dice_wt: 0.8938 - val_loss: 0.3397 - learning_rate: 1.8750e-04
# Epoch 35/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - dice_et: 0.8709 - dice_tc: 0.8980 - dice_wt: 0.9121 - loss: 0.2197
# Epoch 35: val_loss did not improve from 0.32623
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 199s 199ms/step - dice_et: 0.8721 - dice_tc: 0.8969 - dice_wt: 0.9120 - loss: 0.2220 - val_dice_et: 0.8184 - val_dice_tc: 0.8484 - val_dice_wt: 0.8946 - val_loss: 0.3485 - learning_rate: 1.8750e-04
# Epoch 36/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - dice_et: 0.8670 - dice_tc: 0.8953 - dice_wt: 0.9122 - loss: 0.2298
# Epoch 36: val_loss did not improve from 0.32623
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 9.375000081490725e-05.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 197s 197ms/step - dice_et: 0.8668 - dice_tc: 0.8950 - dice_wt: 0.9115 - loss: 0.2297 - val_dice_et: 0.8127 - val_dice_tc: 0.8437 - val_dice_wt: 0.8947 - val_loss: 0.3441 - learning_rate: 1.8750e-04
# Epoch 37/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - dice_et: 0.8707 - dice_tc: 0.8989 - dice_wt: 0.9130 - loss: 0.2217
# Epoch 37: val_loss did not improve from 0.32623
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 201s 201ms/step - dice_et: 0.8723 - dice_tc: 0.8993 - dice_wt: 0.9134 - loss: 0.2211 - val_dice_et: 0.8238 - val_dice_tc: 0.8461 - val_dice_wt: 0.8921 - val_loss: 0.3392 - learning_rate: 9.3750e-05
# Epoch 38/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - dice_et: 0.8754 - dice_tc: 0.9024 - dice_wt: 0.9140 - loss: 0.2145
# Epoch 38: val_loss did not improve from 0.32623
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 202s 202ms/step - dice_et: 0.8726 - dice_tc: 0.8985 - dice_wt: 0.9125 - loss: 0.2198 - val_dice_et: 0.8234 - val_dice_tc: 0.8492 - val_dice_wt: 0.8954 - val_loss: 0.3445 - learning_rate: 9.3750e-05
# Epoch 39/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - dice_et: 0.8717 - dice_tc: 0.8991 - dice_wt: 0.9116 - loss: 0.2280
# Epoch 39: val_loss did not improve from 0.32623
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 205s 205ms/step - dice_et: 0.8729 - dice_tc: 0.8994 - dice_wt: 0.9127 - loss: 0.2235 - val_dice_et: 0.8129 - val_dice_tc: 0.8524 - val_dice_wt: 0.8947 - val_loss: 0.3500 - learning_rate: 9.3750e-05
# Epoch 40/40
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - dice_et: 0.8775 - dice_tc: 0.9023 - dice_wt: 0.9139 - loss: 0.2155
# Epoch 40: val_loss improved from 0.32623 to 0.32443, saving model to /home/zak/brats_project/outputs/best_agresunet_brats2019_40epochs_npy_generator.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 200s 200ms/step - dice_et: 0.8740 - dice_tc: 0.9002 - dice_wt: 0.9131 - loss: 0.2183 - val_dice_et: 0.8215 - val_dice_tc: 0.8564 - val_dice_wt: 0.8956 - val_loss: 0.3244 - learning_rate: 9.3750e-05
#
# Training finished for: brats2019
# Training time in minutes: 134.61
# Best model saved to: /home/zak/brats_project/outputs/best_agresunet_brats2019_40epochs_npy_generator.keras
# Final model saved to: /home/zak/brats_project/outputs/final_agresunet_brats2019_40epochs_npy_generator.keras
# Training log saved to: /home/zak/brats_project/outputs/training_log_brats2019_40epochs_npy_generator.csv

# %%
def load_validation_from_processed(dataset_name, max_eval_slices=1000):
    """
    Loads validation samples from preprocessed .npy patients.
    Uses tumor-centered crops.
    Limits number of samples to avoid RAM crash.
    """
    val_patients = DATASET_SPLITS[dataset_name]["val_patients"]

    processed_val = [
        PROCESSED_DIR / dataset_name / safe_patient_name(p)
        for p in val_patients
        if (PROCESSED_DIR / dataset_name / safe_patient_name(p)).exists()
    ]

    X_list = []
    y_list = []

    print("Processed validation patients:", len(processed_val))

    for patient_dir in tqdm(processed_val):
        image = np.load(patient_dir / "image_4ch.npy", mmap_mode="r")
        mask = np.load(patient_dir / "mask.npy", mmap_mode="r")
        valid_slices = np.load(patient_dir / "valid_slices.npy")

        if len(valid_slices) == 0:
            continue

        for z in valid_slices:
            z = int(z)

            img_slice = np.asarray(image[:, :, z, :], dtype=np.float32)
            mask_slice = np.asarray(mask[:, :, z], dtype=np.uint8)

            X, y_mask = tumor_center_crop_128(img_slice, mask_slice)
            y = one_hot_mask(y_mask)

            X_list.append(X)
            y_list.append(y)

            if len(X_list) >= max_eval_slices:
                break

        if len(X_list) >= max_eval_slices:
            break

    X_val = np.array(X_list, dtype=np.float32)
    y_val = np.array(y_list, dtype=np.float32)

    return X_val, y_val

# %%
# ============================================================
# Cell 11: Evaluate best saved model for each dataset
# Includes Dice + HD95 + plots + example prediction
# ============================================================

import pandas as pd
import matplotlib.pyplot as plt
import gc
from scipy.ndimage import binary_erosion, distance_transform_edt


# -----------------------------
# Hard Dice calculation
# -----------------------------
def hard_dice(true_masks, pred_masks, labels):
    scores = []

    for i in range(true_masks.shape[0]):
        true_region = np.isin(true_masks[i], labels)
        pred_region = np.isin(pred_masks[i], labels)

        intersection = np.sum(true_region & pred_region)
        total = np.sum(true_region) + np.sum(pred_region)

        if total > 0:
            dice = (2 * intersection + 1e-7) / (total + 1e-7)
            scores.append(dice)

    if len(scores) == 0:
        return 0.0

    return np.mean(scores)


# -----------------------------
# HD95 calculation
# -----------------------------
def get_surface(mask):
    mask = mask.astype(bool)

    if mask.sum() == 0:
        return mask

    eroded = binary_erosion(mask)
    surface = mask ^ eroded

    return surface


def hd95_one_case(true_region, pred_region):
    # HD95 cannot be calculated fairly if one region is empty
    if true_region.sum() == 0 or pred_region.sum() == 0:
        return np.nan

    true_surface = get_surface(true_region)
    pred_surface = get_surface(pred_region)

    # Distances from predicted surface to true surface
    true_distance = distance_transform_edt(~true_surface)
    pred_to_true = true_distance[pred_surface]

    # Distances from true surface to predicted surface
    pred_distance = distance_transform_edt(~pred_surface)
    true_to_pred = pred_distance[true_surface]

    all_distances = np.concatenate([pred_to_true, true_to_pred])

    return np.percentile(all_distances, 95)


def mean_hd95(true_masks, pred_masks, labels):
    scores = []

    for i in range(true_masks.shape[0]):
        true_region = np.isin(true_masks[i], labels)
        pred_region = np.isin(pred_masks[i], labels)

        score = hd95_one_case(true_region, pred_region)
        scores.append(score)

    scores = np.array(scores, dtype="float32")

    mean_score = np.nanmean(scores)
    valid_cases = np.sum(~np.isnan(scores))
    total_cases = len(scores)

    return mean_score, valid_cases, total_cases


# -----------------------------
# Evaluate one dataset
# -----------------------------
def evaluate_one_dataset(dataset_name, example_index=0):
    print("\n" + "=" * 80)
    print("EVALUATING DATASET:", dataset_name)
    print("=" * 80)

    checkpoint_path = OUTPUT_DIR / f"best_agresunet_{dataset_name}_40epochs_npy_generator.keras"
    final_model_path = OUTPUT_DIR / f"final_agresunet_{dataset_name}_40epochs_npy_generator.keras"
    log_path = OUTPUT_DIR / f"training_log_{dataset_name}_40epochs_npy_generator.csv"
    print("\nCheckpoint path:")
    print(checkpoint_path)

    print("\nLog path:")
    print(log_path)

    # -----------------------------
    # Read training log
    # -----------------------------
    log_df = pd.read_csv(log_path)

    print("\nTraining log:")
    display(log_df)

    # Find best epoch using validation loss
    best_row = log_df.loc[log_df["val_loss"].idxmin()]

    print("\nBest epoch:", int(best_row["epoch"]) + 1)
    print("Best val_loss:", best_row["val_loss"])
    print("Best soft val_dice_wt:", best_row["val_dice_wt"])
    print("Best soft val_dice_tc:", best_row["val_dice_tc"])
    print("Best soft val_dice_et:", best_row["val_dice_et"])

    # -----------------------------
    # Preload validation data again
    # -----------------------------
    print("\nReloading validation data from preprocessed .npy files...")
    X_val_full, y_val_full = load_validation_from_processed(
        dataset_name,
        max_eval_slices=1000
    )

    print("\nValidation data loaded:")
    print("X_val_full:", X_val_full.shape)
    print("y_val_full:", y_val_full.shape)

    print("\nValidation labels:", np.unique(np.argmax(y_val_full, axis=-1)))

    # -----------------------------
    # Load best model
    # -----------------------------
    best_model = tf.keras.models.load_model(
        checkpoint_path,
        compile=False
    )

    print("\nLoaded best model from:")
    print(checkpoint_path)

    # -----------------------------
    # Predict on validation data
    # -----------------------------
    pred_probs = best_model.predict(
        X_val_full,
        batch_size=8,
        verbose=1
    )

    true_masks = np.argmax(y_val_full, axis=-1)
    pred_masks = np.argmax(pred_probs, axis=-1)

    print("\nTrue labels:", np.unique(true_masks))
    print("Predicted labels:", np.unique(pred_masks))

    # -----------------------------
    # Hard Dice scores
    # -----------------------------
    hard_dice_wt = hard_dice(true_masks, pred_masks, [1, 2, 3])
    hard_dice_tc = hard_dice(true_masks, pred_masks, [1, 3])
    hard_dice_et = hard_dice(true_masks, pred_masks, [3])

    # -----------------------------
    # HD95 scores
    # -----------------------------
    hd95_wt, valid_wt, total_wt = mean_hd95(true_masks, pred_masks, [1, 2, 3])
    hd95_tc, valid_tc, total_tc = mean_hd95(true_masks, pred_masks, [1, 3])
    hd95_et, valid_et, total_et = mean_hd95(true_masks, pred_masks, [3])

    hd95_table = pd.DataFrame({
        "Dataset": [dataset_name, dataset_name, dataset_name],
        "Region": ["WT", "TC", "ET"],
        "Labels used": ["1,2,3", "1,3", "3"],
        "Mean HD95": [hd95_wt, hd95_tc, hd95_et],
        "Valid cases": [valid_wt, valid_tc, valid_et],
        "Total cases": [total_wt, total_tc, total_et]
    })

    print("\nHD95 results:")
    display(hd95_table)

    # -----------------------------
    # Final results table
    # -----------------------------
    results_table = pd.DataFrame({
        "Dataset": [dataset_name],
        "Run": [f"{dataset_name} full 40-epoch preloaded run"],
        "Best epoch": [int(best_row["epoch"]) + 1],
        "Validation samples": [len(X_val_full)],
        "Best val_loss": [best_row["val_loss"]],
        "Soft Dice WT": [best_row["val_dice_wt"]],
        "Soft Dice TC": [best_row["val_dice_tc"]],
        "Soft Dice ET": [best_row["val_dice_et"]],
        "Hard Dice WT": [hard_dice_wt],
        "Hard Dice TC": [hard_dice_tc],
        "Hard Dice ET": [hard_dice_et],
        "HD95 WT": [hd95_wt],
        "HD95 TC": [hd95_tc],
        "HD95 ET": [hd95_et]
    })

    print("\nFinal validation result table:")
    display(results_table)

    # -----------------------------
    # Plot loss curve
    # -----------------------------
    plt.figure(figsize=(7, 4))
    plt.plot(log_df["epoch"] + 1, log_df["loss"], marker="o", label="Train loss")
    plt.plot(log_df["epoch"] + 1, log_df["val_loss"], marker="o", label="Val loss")
    plt.axvline(int(best_row["epoch"]) + 1, linestyle="--", label="Best epoch")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(f"{dataset_name}: Training and validation loss")
    plt.legend()
    plt.grid(True)
    plt.show()

    # -----------------------------
    # Plot validation Dice
    # -----------------------------
    plt.figure(figsize=(7, 4))
    plt.plot(log_df["epoch"] + 1, log_df["val_dice_wt"], marker="o", label="WT")
    plt.plot(log_df["epoch"] + 1, log_df["val_dice_tc"], marker="o", label="TC")
    plt.plot(log_df["epoch"] + 1, log_df["val_dice_et"], marker="o", label="ET")
    plt.axvline(int(best_row["epoch"]) + 1, linestyle="--", label="Best epoch")
    plt.xlabel("Epoch")
    plt.ylabel("Validation Dice")
    plt.title(f"{dataset_name}: Validation Dice scores")
    plt.legend()
    plt.grid(True)
    plt.show()

    # -----------------------------
    # Show one example prediction
    # -----------------------------
    i = example_index

    if i >= len(X_val_full):
        i = 0

    plt.figure(figsize=(12, 4))

    plt.subplot(1, 3, 1)
    plt.imshow(X_val_full[i, :, :, 0], cmap="gray")
    plt.title(f"{dataset_name} Validation Flair")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(true_masks[i])
    plt.title("Ground truth")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(pred_masks[i])
    plt.title("Prediction")
    plt.axis("off")

    plt.tight_layout()
    plt.show()

    # -----------------------------
    # Clear RAM after this dataset
    # -----------------------------
    del X_val_full, y_val_full
    del pred_probs, true_masks, pred_masks
    del best_model
    gc.collect()
    tf.keras.backend.clear_session()

    return results_table, hd95_table

# %%
# ============================================================
# Cell 12: Run evaluation for BraTS 2017, 2018, and 2019
# ============================================================

all_results = []
all_hd95_results = []

for dataset_name in ["brats2017", "brats2018", "brats2019"]:
    result_table, hd95_table = evaluate_one_dataset(dataset_name, example_index=0)

    all_results.append(result_table)
    all_hd95_results.append(hd95_table)

final_results_table = pd.concat(all_results, ignore_index=True)
final_hd95_table = pd.concat(all_hd95_results, ignore_index=True)

print("\nAll dataset Dice + loss results:")
display(final_results_table)

print("\nAll dataset HD95 results:")
display(final_hd95_table)
# Out:
# ================================================================================
# EVALUATING DATASET: brats2017
# ================================================================================
#
# Checkpoint path:
# /home/zak/brats_project/outputs/best_agresunet_brats2017_40epochs_npy_generator.keras
#
# Log path:
# /home/zak/brats_project/outputs/training_log_brats2017_40epochs_npy_generator.csv
#
# Training log:
#     epoch   dice_et   dice_tc   dice_wt      loss  val_dice_et  val_dice_tc  \
# 0       0  0.653352  0.580682  0.777271  0.849108     0.723007     0.644613
# 1       1  0.736968  0.706163  0.822543  0.494260     0.744525     0.695030
# 2       2  0.753988  0.738479  0.840926  0.442326     0.769672     0.725452
# 3       3  0.771649  0.768554  0.856399  0.406311     0.772629     0.747785
# 4       4  0.779707  0.784360  0.863303  0.392300     0.795523     0.722755
# 5       5  0.792766  0.800624  0.868433  0.364844     0.803530     0.761350
# 6       6  0.796109  0.803512  0.867965  0.360868     0.793079     0.763770
# 7       7  0.793317  0.817496  0.870888  0.347714     0.798611     0.758010
# 8       8  0.795809  0.817631  0.873497  0.349345     0.785474     0.768401
# 9       9  0.802491  0.831236  0.879923  0.324263     0.822009     0.773931
# 10     10  0.806981  0.825566  0.879226  0.334132     0.817013     0.784744
# 11     11  0.806705  0.839934  0.882270  0.319285     0.811471     0.780375
# 12     12  0.812598  0.831745  0.878929  0.321306     0.806826     0.764798
# 13     13  0.815364  0.848554  0.887806  0.305625     0.816130     0.788945
# 14     14  0.814959  0.846871  0.884599  0.309521     0.825230     0.778084
# 15     15  0.813422  0.851124  0.888442  0.306644     0.814034     0.788483
# 16     16  0.820264  0.857425  0.889735  0.292235     0.824326     0.783236
# 17     17  0.821233  0.855510  0.887720  0.298685     0.821205     0.763485
# 18     18  0.805346  0.845227  0.883266  0.313025     0.818074     0.767446
# 19     19  0.816337  0.851650  0.886357  0.301144     0.797821     0.766985
# 20     20  0.823916  0.859926  0.891882  0.287897     0.813004     0.749258
# 21     21  0.835264  0.867206  0.893088  0.269639     0.821414     0.790569
# 22     22  0.837924  0.878167  0.898879  0.256626     0.823046     0.778693
# 23     23  0.836976  0.877823  0.898308  0.262046     0.820417     0.775624
# 24     24  0.836474  0.876990  0.898933  0.256487     0.822898     0.779211
# 25     25  0.838700  0.886323  0.899284  0.251042     0.819986     0.782102
# 26     26  0.842549  0.885864  0.903031  0.247030     0.822593     0.758791
# 27     27  0.850260  0.893025  0.902735  0.238651     0.811743     0.753756
# 28     28  0.847745  0.891128  0.903064  0.238624     0.816707     0.793095
# 29     29  0.849473  0.888562  0.903496  0.238055     0.821701     0.792962
# 30     30  0.853748  0.891988  0.905001  0.234183     0.816609     0.775526
# 31     31  0.855416  0.894120  0.904659  0.229757     0.822876     0.780350
# 32     32  0.851276  0.889183  0.901309  0.237293     0.814970     0.789297
# 33     33  0.853827  0.893938  0.904413  0.229930     0.824016     0.776098
# 34     34  0.858516  0.897723  0.907289  0.225794     0.825303     0.788986
# 35     35  0.861740  0.901209  0.906795  0.217956     0.829646     0.790804
# 36     36  0.858283  0.901243  0.905944  0.221718     0.833189     0.791251
# 37     37  0.862968  0.899532  0.907519  0.216660     0.822142     0.780402
# 38     38  0.861785  0.903068  0.909151  0.214616     0.819324     0.775875
# 39     39  0.861987  0.902070  0.907225  0.212990     0.825896     0.770170
#
#     val_dice_wt  val_loss
# 0      0.814060  0.594691
# 1      0.838146  0.565059
# 2      0.865258  0.472779
# 3      0.854093  0.485302
# 4      0.847335  0.467394
# 5      0.847765  0.430908
# 6      0.872497  0.448193
# 7      0.870562  0.467524
# 8      0.869403  0.454422
# 9      0.885168  0.429729
# 10     0.870288  0.439306
# 11     0.871908  0.422707
# 12     0.864168  0.428371
# 13     0.868028  0.437769
# 14     0.881167  0.444983
# 15     0.882097  0.411745
# 16     0.881732  0.442369
# 17     0.877896  0.413801
# 18     0.878805  0.416516
# 19     0.878213  0.470150
# 20     0.881590  0.449184
# 21     0.883711  0.418847
# 22     0.886916  0.422213
# 23     0.885718  0.415205
# 24     0.882763  0.426896
# 25     0.889193  0.418046
# 26     0.881291  0.437883
# 27     0.882925  0.462499
# 28     0.877059  0.413548
# 29     0.887485  0.410864
# 30     0.884078  0.418337
# 31     0.888550  0.412267
# 32     0.887943  0.425813
# 33     0.882669  0.416202
# 34     0.886188  0.419967
# 35     0.885878  0.407789
# 36     0.887633  0.398432
# 37     0.884388  0.432915
# 38     0.890252  0.429902
# 39     0.884613  0.437187
# Best epoch: 37
# Best val_loss: 0.3984315097332001
# Best soft val_dice_wt: 0.8876326084136963
# Best soft val_dice_tc: 0.7912505269050598
# Best soft val_dice_et: 0.8331891298294067
#
# Reloading validation data from preprocessed .npy files...
# Processed validation patients: 57
#  26%|█████████████████████▊                                                             | 15/57 [00:02<00:07,  5.36it/s]
# Validation data loaded:
# X_val_full: (1000, 128, 128, 4)
# y_val_full: (1000, 128, 128, 4)
#
# Validation labels: [0 1 2 3]
#
# Loaded best model from:
# /home/zak/brats_project/outputs/best_agresunet_brats2017_40epochs_npy_generator.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step
#
# True labels: [0 1 2 3]
# Predicted labels: [0 1 2 3]
#
# HD95 results:
#      Dataset Region Labels used  Mean HD95  Valid cases  Total cases
# 0  brats2017     WT       1,2,3   9.776387          979         1000
# 1  brats2017     TC         1,3   6.385866          614         1000
# 2  brats2017     ET           3   4.573255          525         1000
# Final validation result table:
#      Dataset                                    Run  Best epoch  \
# 0  brats2017  brats2017 full 40-epoch preloaded run          37
#
#    Validation samples  Best val_loss  Soft Dice WT  Soft Dice TC  \
# 0                1000       0.398432      0.887633      0.791251
#
#    Soft Dice ET  Hard Dice WT  Hard Dice TC  Hard Dice ET   HD95 WT   HD95 TC  \
# 0      0.833189      0.812509      0.670758      0.637816  9.776387  6.385866
#
#     HD95 ET
# 0  4.573255
# ================================================================================
# EVALUATING DATASET: brats2018
# ================================================================================
#
# Checkpoint path:
# /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
#
# Log path:
# /home/zak/brats_project/outputs/training_log_brats2018_40epochs_npy_generator.csv
#
# Training log:
#     epoch   dice_et       dice_tc   dice_wt      loss  val_dice_et  \
# 0       0  0.017010  1.670561e-02  0.779459  1.808496     0.004000
# 1       1  0.004000  3.079886e-11  0.824176  1.763203     0.007907
# 2       2  0.000038  1.544110e-01  0.804915  1.767359     0.002094
# 3       3  0.169394  6.001166e-01  0.822754  1.429060     0.714233
# 4       4  0.697570  6.291121e-01  0.834505  0.997190     0.716230
# 5       5  0.736203  7.335408e-01  0.854316  0.814434     0.763496
# 6       6  0.767734  7.669382e-01  0.859182  0.702893     0.760484
# 7       7  0.771811  7.694573e-01  0.854281  0.468910     0.758067
# 8       8  0.790895  7.943734e-01  0.861970  0.389274     0.797508
# 9       9  0.793633  7.877720e-01  0.860665  0.391638     0.780559
# 10     10  0.797843  8.149462e-01  0.869868  0.363291     0.792528
# 11     11  0.811118  8.104140e-01  0.872051  0.351305     0.800861
# 12     12  0.806772  8.187442e-01  0.874107  0.343226     0.799225
# 13     13  0.807211  8.210437e-01  0.875760  0.351574     0.797907
# 14     14  0.813493  8.186343e-01  0.876152  0.339174     0.819158
# 15     15  0.811294  8.318205e-01  0.879637  0.333493     0.822713
# 16     16  0.821043  8.407820e-01  0.884027  0.317949     0.801303
# 17     17  0.821309  8.339372e-01  0.881713  0.322563     0.815165
# 18     18  0.817879  8.346508e-01  0.883072  0.324829     0.813829
# 19     19  0.817066  8.328213e-01  0.884049  0.323133     0.818135
# 20     20  0.818482  8.400637e-01  0.882562  0.317325     0.797933
# 21     21  0.832799  8.572728e-01  0.889242  0.291888     0.821905
# 22     22  0.836494  8.631916e-01  0.893860  0.281315     0.822330
# 23     23  0.839562  8.652112e-01  0.894276  0.276138     0.810298
# 24     24  0.842026  8.667094e-01  0.892753  0.276132     0.808866
# 25     25  0.839473  8.672577e-01  0.894134  0.274437     0.827260
# 26     26  0.846605  8.733528e-01  0.897697  0.262940     0.813820
# 27     27  0.842516  8.738031e-01  0.896802  0.265247     0.823378
# 28     28  0.847743  8.739239e-01  0.897140  0.259050     0.834498
# 29     29  0.855136  8.848522e-01  0.900718  0.244976     0.836512
# 30     30  0.857266  8.838759e-01  0.901153  0.245834     0.819529
# 31     31  0.855239  8.824654e-01  0.899261  0.248250     0.826857
# 32     32  0.851938  8.853227e-01  0.900805  0.248875     0.835114
# 33     33  0.858773  8.892984e-01  0.902700  0.238808     0.828346
# 34     34  0.859085  8.903435e-01  0.902566  0.238943     0.811217
# 35     35  0.856386  8.908615e-01  0.903167  0.239970     0.829957
# 36     36  0.860541  8.930637e-01  0.903353  0.230938     0.836227
# 37     37  0.857625  8.930674e-01  0.904085  0.234879     0.827926
# 38     38  0.869973  8.980414e-01  0.904764  0.221307     0.818989
# 39     39  0.859464  8.970500e-01  0.905919  0.227632     0.819297
#
#      val_dice_tc  val_dice_wt  val_loss
# 0   3.244106e-11     0.850809  1.691221
# 1   4.322911e-10     0.808060  1.682478
# 2   5.211240e-01     0.795729  1.728550
# 3   5.900906e-01     0.839814  0.999662
# 4   6.411805e-01     0.828797  0.909912
# 5   7.335826e-01     0.844506  0.737962
# 6   7.750317e-01     0.873839  0.575206
# 7   7.656109e-01     0.855929  0.458264
# 8   7.442088e-01     0.880673  0.438566
# 9   7.583548e-01     0.819738  0.422909
# 10  7.825306e-01     0.868472  0.416417
# 11  7.432247e-01     0.854856  0.415516
# 12  7.714579e-01     0.863540  0.405885
# 13  7.809633e-01     0.858822  0.390416
# 14  7.882525e-01     0.869389  0.377705
# 15  7.856734e-01     0.880171  0.366692
# 16  7.896670e-01     0.880600  0.390583
# 17  7.907986e-01     0.873306  0.366793
# 18  7.702602e-01     0.843864  0.394597
# 19  7.835836e-01     0.863832  0.389613
# 20  7.839027e-01     0.881675  0.397595
# 21  7.893849e-01     0.878195  0.376775
# 22  8.094968e-01     0.886344  0.342150
# 23  7.948046e-01     0.881504  0.384110
# 24  7.883394e-01     0.881260  0.381095
# 25  8.075202e-01     0.882209  0.361760
# 26  7.990114e-01     0.875202  0.369679
# 27  7.911577e-01     0.874481  0.363967
# 28  8.021159e-01     0.876944  0.340269
# 29  8.055568e-01     0.888240  0.352273
# 30  7.910540e-01     0.888295  0.372374
# 31  7.927463e-01     0.887484  0.353774
# 32  8.102314e-01     0.902461  0.348240
# 33  8.157589e-01     0.871114  0.352680
# 34  8.035745e-01     0.884261  0.367876
# 35  8.101965e-01     0.882550  0.344815
# 36  8.254587e-01     0.893389  0.346079
# 37  8.059599e-01     0.887977  0.357315
# 38  8.124487e-01     0.891228  0.351930
# 39  8.198807e-01     0.888901  0.351165
# Best epoch: 29
# Best val_loss: 0.3402693569660187
# Best soft val_dice_wt: 0.8769439458847046
# Best soft val_dice_tc: 0.8021159172058105
# Best soft val_dice_et: 0.8344976305961609
#
# Reloading validation data from preprocessed .npy files...
# Processed validation patients: 57
#  26%|█████████████████████▊                                                             | 15/57 [00:02<00:08,  5.16it/s]
# Validation data loaded:
# X_val_full: (1000, 128, 128, 4)
# y_val_full: (1000, 128, 128, 4)
#
# Validation labels: [0 1 2 3]
#
# Loaded best model from:
# /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step
#
# True labels: [0 1 2 3]
# Predicted labels: [0 1 2 3]
#
# HD95 results:
#      Dataset Region Labels used  Mean HD95  Valid cases  Total cases
# 0  brats2018     WT       1,2,3   8.813345          976         1000
# 1  brats2018     TC         1,3   6.854973          615         1000
# 2  brats2018     ET           3   6.288176          573         1000
# Final validation result table:
#      Dataset                                    Run  Best epoch  \
# 0  brats2018  brats2018 full 40-epoch preloaded run          29
#
#    Validation samples  Best val_loss  Soft Dice WT  Soft Dice TC  \
# 0                1000       0.340269      0.876944      0.802116
#
#    Soft Dice ET  Hard Dice WT  Hard Dice TC  Hard Dice ET   HD95 WT   HD95 TC  \
# 0      0.834498      0.827601       0.68901      0.670647  8.813345  6.854973
#
#     HD95 ET
# 0  6.288176
# ================================================================================
# EVALUATING DATASET: brats2019
# ================================================================================
#
# Checkpoint path:
# /home/zak/brats_project/outputs/best_agresunet_brats2019_40epochs_npy_generator.keras
#
# Log path:
# /home/zak/brats_project/outputs/training_log_brats2019_40epochs_npy_generator.csv
#
# Training log:
#     epoch   dice_et   dice_tc   dice_wt      loss  val_dice_et  val_dice_tc  \
# 0       0  0.708960  0.601744  0.797494  0.839453     0.745395     0.666002
# 1       1  0.784088  0.741564  0.840550  0.450059     0.767688     0.729432
# 2       2  0.805819  0.766301  0.858191  0.402371     0.788918     0.748985
# 3       3  0.807117  0.774533  0.869313  0.386713     0.778182     0.782556
# 4       4  0.816478  0.792915  0.870325  0.369897     0.807540     0.804939
# 5       5  0.823121  0.795168  0.873807  0.361546     0.778686     0.784624
# 6       6  0.829176  0.813144  0.881049  0.337981     0.820538     0.809606
# 7       7  0.832240  0.811168  0.883692  0.333731     0.799251     0.807264
# 8       8  0.834564  0.822787  0.885464  0.329968     0.816368     0.808982
# 9       9  0.839702  0.830606  0.888283  0.317701     0.811446     0.828933
# 10     10  0.829082  0.827160  0.887870  0.318651     0.789664     0.817959
# 11     11  0.838258  0.825388  0.886638  0.319995     0.801355     0.818728
# 12     12  0.847562  0.843886  0.894649  0.296564     0.811767     0.824976
# 13     13  0.843598  0.852150  0.896807  0.286739     0.825310     0.843679
# 14     14  0.852558  0.860383  0.900148  0.273484     0.813024     0.843158
# 15     15  0.851105  0.859870  0.900008  0.275010     0.813237     0.825467
# 16     16  0.850214  0.853855  0.898322  0.279793     0.821955     0.828412
# 17     17  0.851964  0.865343  0.900360  0.271059     0.818606     0.815134
# 18     18  0.858966  0.865586  0.902707  0.268978     0.814938     0.841109
# 19     19  0.855518  0.868100  0.904112  0.259527     0.813794     0.840497
# 20     20  0.858810  0.871770  0.904494  0.258504     0.815213     0.838559
# 21     21  0.857443  0.877348  0.905280  0.256452     0.820814     0.849839
# 22     22  0.863355  0.881732  0.907032  0.250327     0.815591     0.852933
# 23     23  0.860288  0.876020  0.904008  0.255581     0.805289     0.828048
# 24     24  0.861999  0.881056  0.906686  0.246447     0.824493     0.843549
# 25     25  0.868511  0.886041  0.909071  0.239494     0.811253     0.832351
# 26     26  0.872948  0.893197  0.910481  0.227894     0.822870     0.849047
# 27     27  0.867308  0.892564  0.911061  0.234993     0.805666     0.840797
# 28     28  0.871201  0.892101  0.911193  0.225768     0.808819     0.827403
# 29     29  0.869803  0.892121  0.910444  0.231194     0.815844     0.861897
# 30     30  0.872627  0.892954  0.909698  0.231917     0.822088     0.830694
# 31     31  0.867886  0.898139  0.911421  0.228211     0.822343     0.853356
# 32     32  0.869637  0.894304  0.910559  0.224945     0.821035     0.844935
# 33     33  0.870553  0.896835  0.912759  0.220605     0.826246     0.847644
# 34     34  0.872139  0.896906  0.911988  0.222018     0.818436     0.848406
# 35     35  0.866841  0.895002  0.911498  0.229687     0.812687     0.843737
# 36     36  0.872265  0.899261  0.913449  0.221121     0.823814     0.846105
# 37     37  0.872626  0.898483  0.912526  0.219790     0.823366     0.849228
# 38     38  0.872873  0.899390  0.912655  0.223468     0.812874     0.852353
# 39     39  0.874048  0.900154  0.913145  0.218313     0.821480     0.856385
#
#     val_dice_wt  val_loss
# 0      0.801000  0.580832
# 1      0.781430  0.473139
# 2      0.852985  0.437195
# 3      0.870408  0.423797
# 4      0.871646  0.382878
# 5      0.858419  0.394883
# 6      0.876044  0.359955
# 7      0.883450  0.397759
# 8      0.885546  0.362470
# 9      0.853861  0.367353
# 10     0.877521  0.365035
# 11     0.881660  0.398901
# 12     0.880516  0.357215
# 13     0.882209  0.332701
# 14     0.892390  0.346982
# 15     0.880019  0.353856
# 16     0.888827  0.348491
# 17     0.885842  0.388239
# 18     0.890763  0.360945
# 19     0.889892  0.336569
# 20     0.885131  0.326232
# 21     0.889850  0.330882
# 22     0.885138  0.337863
# 23     0.881820  0.354586
# 24     0.888852  0.332680
# 25     0.887118  0.342410
# 26     0.895006  0.332723
# 27     0.893897  0.358016
# 28     0.892059  0.351768
# 29     0.897402  0.329214
# 30     0.887255  0.339313
# 31     0.893164  0.334782
# 32     0.897037  0.344071
# 33     0.893838  0.339732
# 34     0.894552  0.348473
# 35     0.894658  0.344114
# 36     0.892091  0.339203
# 37     0.895447  0.344542
# 38     0.894708  0.349996
# 39     0.895612  0.324429
# Best epoch: 40
# Best val_loss: 0.3244288265705108
# Best soft val_dice_wt: 0.8956117630004883
# Best soft val_dice_tc: 0.8563852310180664
# Best soft val_dice_et: 0.8214804530143738
#
# Reloading validation data from preprocessed .npy files...
# Processed validation patients: 67
#  22%|██████████████████▌                                                                | 15/67 [00:01<00:06,  8.30it/s]
# Validation data loaded:
# X_val_full: (1000, 128, 128, 4)
# y_val_full: (1000, 128, 128, 4)
#
# Validation labels: [0 1 2 3]
#
# Loaded best model from:
# /home/zak/brats_project/outputs/best_agresunet_brats2019_40epochs_npy_generator.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step
#
# True labels: [0 1 2 3]
# Predicted labels: [0 1 2 3]
#
# HD95 results:
#      Dataset Region Labels used  Mean HD95  Valid cases  Total cases
# 0  brats2019     WT       1,2,3   8.367290          973         1000
# 1  brats2019     TC         1,3   9.753166          669         1000
# 2  brats2019     ET           3   9.354920          546         1000
# Final validation result table:
#      Dataset                                    Run  Best epoch  \
# 0  brats2019  brats2019 full 40-epoch preloaded run          40
#
#    Validation samples  Best val_loss  Soft Dice WT  Soft Dice TC  \
# 0                1000       0.324429      0.895612      0.856385
#
#    Soft Dice ET  Hard Dice WT  Hard Dice TC  Hard Dice ET  HD95 WT   HD95 TC  \
# 0       0.82148       0.82828      0.645153      0.640218  8.36729  9.753166
#
#    HD95 ET
# 0  9.35492
# All dataset Dice + loss results:
#      Dataset                                    Run  Best epoch  \
# 0  brats2017  brats2017 full 40-epoch preloaded run          37
# 1  brats2018  brats2018 full 40-epoch preloaded run          29
# 2  brats2019  brats2019 full 40-epoch preloaded run          40
#
#    Validation samples  Best val_loss  Soft Dice WT  Soft Dice TC  \
# 0                1000       0.398432      0.887633      0.791251
# 1                1000       0.340269      0.876944      0.802116
# 2                1000       0.324429      0.895612      0.856385
#
#    Soft Dice ET  Hard Dice WT  Hard Dice TC  Hard Dice ET   HD95 WT   HD95 TC  \
# 0      0.833189      0.812509      0.670758      0.637816  9.776387  6.385866
# 1      0.834498      0.827601      0.689010      0.670647  8.813345  6.854973
# 2      0.821480      0.828280      0.645153      0.640218  8.367290  9.753166
#
#     HD95 ET
# 0  4.573255
# 1  6.288176
# 2  9.354920
# All dataset HD95 results:
#      Dataset Region Labels used  Mean HD95  Valid cases  Total cases
# 0  brats2017     WT       1,2,3   9.776387          979         1000
# 1  brats2017     TC         1,3   6.385866          614         1000
# 2  brats2017     ET           3   4.573255          525         1000
# 3  brats2018     WT       1,2,3   8.813345          976         1000
# 4  brats2018     TC         1,3   6.854973          615         1000
# 5  brats2018     ET           3   6.288176          573         1000
# 6  brats2019     WT       1,2,3   8.367290          973         1000
# 7  brats2019     TC         1,3   9.753166          669         1000
# 8  brats2019     ET           3   9.354920          546         1000

# %%
# ============================================================
# Cell 12b: 3D volumetric Dice evaluation on test patients
# Reconstructs full 3D predictions patient by patient.
# This is added as an evaluation-only enhancement.
# It does not change loading, preprocessing, augmentation, training,
# parameters, losses, or the saved models.
# ============================================================

# Paper AGResU-Net Dice values from Table 8
# BraTS 2017 validation: WT/TC/ET = 0.880, 0.781, 0.749
# BraTS 2018 validation: WT/TC/ET = 0.872, 0.808, 0.772
# BraTS 2019 validation: WT/TC/ET = 0.870, 0.777, 0.709
PAPER_DICE_3D = {
    "brats2017": {"WT": 0.880, "TC": 0.781, "ET": 0.749},
    "brats2018": {"WT": 0.872, "TC": 0.808, "ET": 0.772},
    "brats2019": {"WT": 0.870, "TC": 0.777, "ET": 0.709},
}


def center_crop_coords(h, w, size=128):
    """Return the fixed center-crop coordinates used for 3D reconstruction."""
    start_h = (h - size) // 2
    start_w = (w - size) // 2
    return start_h, start_w


def volumetric_dice_score(true_vol, pred_vol, labels):
    """Compute Dice on a whole 3D volume for one BraTS region."""
    true_region = np.isin(true_vol, labels)
    pred_region = np.isin(pred_vol, labels)

    intersection = np.sum(true_region & pred_region)
    total = np.sum(true_region) + np.sum(pred_region)

    if total == 0:
        return np.nan

    return (2.0 * intersection + 1e-7) / (total + 1e-7)


def evaluate_processed_patient_3d(processed_patient_dir, model, patch_size=128):
    """
    Run slice-by-slice inference on one preprocessed 3D patient.

    The model predicts a 128x128 patch for every axial slice.
    The predicted patch is inserted back into a full-size 3D prediction volume,
    then Dice is calculated over the full 3D patient volume.
    """
    processed_patient_dir = Path(processed_patient_dir)

    image_vol = np.load(processed_patient_dir / "image_4ch.npy", mmap_mode="r")
    mask_vol = np.load(processed_patient_dir / "mask.npy", mmap_mode="r")

    h, w, depth, channels = image_vol.shape
    start_h, start_w = center_crop_coords(h, w, patch_size)

    pred_vol = np.zeros(mask_vol.shape, dtype=np.uint8)

    for z in range(depth):
        image_slice = np.asarray(image_vol[:, :, z, :], dtype=np.float32)

        x_patch = image_slice[
            start_h:start_h + patch_size,
            start_w:start_w + patch_size,
            :
        ]

        x_patch = x_patch[np.newaxis, ...]

        pred_probs = model.predict(x_patch, verbose=0)
        pred_patch = np.argmax(pred_probs[0], axis=-1).astype(np.uint8)

        pred_vol[
            start_h:start_h + patch_size,
            start_w:start_w + patch_size,
            z
        ] = pred_patch

    # Internal labels are 0,1,2,3 because label 4 was remapped to 3.
    # Use internal labels for Dice regions:
    # WT = labels 1,2,3 | TC = labels 1,3 | ET = label 3
    return {
        "Dice WT": volumetric_dice_score(mask_vol, pred_vol, [1, 2, 3]),
        "Dice TC": volumetric_dice_score(mask_vol, pred_vol, [1, 3]),
        "Dice ET": volumetric_dice_score(mask_vol, pred_vol, [3]),
    }


def evaluate_one_dataset_3d(dataset_name, max_patients=10):
    """Evaluate 3D volumetric Dice for one dataset using its saved best model."""
    print("\n" + "=" * 80)
    print("3D VOLUMETRIC DICE EVALUATION:", dataset_name)
    print("=" * 80)

    checkpoint_path = OUTPUT_DIR / f"best_agresunet_{dataset_name}_40epochs_npy_generator.keras"

    print("\nLoading best model from:")
    print(checkpoint_path)

    if not checkpoint_path.exists():
        print("Checkpoint not found. Skipping:", checkpoint_path)
        return None, None

    test_patients = DATASET_SPLITS[dataset_name]["test_patients"]

    processed_test = [
        PROCESSED_DIR / dataset_name / safe_patient_name(p)
        for p in test_patients
        if (PROCESSED_DIR / dataset_name / safe_patient_name(p)).exists()
    ]

    if len(processed_test) == 0:
        print("No processed test patients found. Skipping:", dataset_name)
        return None, None

    processed_test = processed_test[:min(max_patients, len(processed_test))]

    print("Processed test patients evaluated:", len(processed_test))

    best_model = tf.keras.models.load_model(
        checkpoint_path,
        compile=False
    )

    patient_rows = []

    for patient_dir in tqdm(processed_test):
        scores = evaluate_processed_patient_3d(
            patient_dir,
            best_model,
            patch_size=PATCH_SIZE
        )

        patient_rows.append({
            "Dataset": dataset_name,
            "Patient": patient_dir.name,
            "Dice WT": scores["Dice WT"],
            "Dice TC": scores["Dice TC"],
            "Dice ET": scores["Dice ET"]
        })

    patient_3d_df = pd.DataFrame(patient_rows)

    paper_values = PAPER_DICE_3D[dataset_name]

    summary_3d_df = pd.DataFrame({
        "Dataset": [dataset_name, dataset_name, dataset_name],
        "Region": ["WT", "TC", "ET"],
        "Labels used internally": ["1,2,3", "1,3", "3"],
        "Mean 3D Dice": [
            float(np.nanmean(patient_3d_df["Dice WT"])),
            float(np.nanmean(patient_3d_df["Dice TC"])),
            float(np.nanmean(patient_3d_df["Dice ET"])),
        ],
        "Paper AGResU-Net Dice": [
            paper_values["WT"],
            paper_values["TC"],
            paper_values["ET"],
        ],
        "Patients evaluated": [
            int(patient_3d_df["Dice WT"].notna().sum()),
            int(patient_3d_df["Dice TC"].notna().sum()),
            int(patient_3d_df["Dice ET"].notna().sum()),
        ]
    })

    summary_3d_df["Difference from paper"] = (
        summary_3d_df["Mean 3D Dice"] - summary_3d_df["Paper AGResU-Net Dice"]
    )

    print("\nPer-patient 3D Dice:")
    display(patient_3d_df)

    print("\n3D volumetric Dice summary:")
    display(summary_3d_df)

    patient_path = OUTPUT_DIR / f"volumetric_dice_3d_patients_{dataset_name}.csv"
    summary_path = OUTPUT_DIR / f"volumetric_dice_3d_summary_{dataset_name}.csv"

    patient_3d_df.to_csv(patient_path, index=False)
    summary_3d_df.to_csv(summary_path, index=False)

    print("\nSaved 3D patient results to:", patient_path)
    print("Saved 3D summary to:", summary_path)

    del best_model
    gc.collect()
    tf.keras.backend.clear_session()

    return patient_3d_df, summary_3d_df


# Run 3D volumetric Dice for all datasets
all_3d_patient_results = []
all_3d_summary_results = []

N_PATIENTS_3D = 10

for dataset_name in ["brats2017", "brats2018", "brats2019"]:
    patient_3d_df, summary_3d_df = evaluate_one_dataset_3d(
        dataset_name,
        max_patients=N_PATIENTS_3D
    )

    if patient_3d_df is not None:
        all_3d_patient_results.append(patient_3d_df)
        all_3d_summary_results.append(summary_3d_df)

if len(all_3d_summary_results) > 0:
    final_3d_patient_results = pd.concat(all_3d_patient_results, ignore_index=True)
    final_3d_summary_table = pd.concat(all_3d_summary_results, ignore_index=True)

    print("\nCombined 3D volumetric Dice patient results:")
    display(final_3d_patient_results)

    print("\nCombined 3D volumetric Dice summary:")
    display(final_3d_summary_table)

    combined_patient_path = OUTPUT_DIR / "volumetric_dice_3d_patients_all_datasets.csv"
    combined_summary_path = OUTPUT_DIR / "volumetric_dice_3d_summary_all_datasets.csv"

    final_3d_patient_results.to_csv(combined_patient_path, index=False)
    final_3d_summary_table.to_csv(combined_summary_path, index=False)

    print("\nSaved combined 3D patient results to:", combined_patient_path)
    print("Saved combined 3D summary to:", combined_summary_path)
else:
    print("No 3D volumetric results were produced.")
# Out:
# ================================================================================
# 3D VOLUMETRIC DICE EVALUATION: brats2017
# ================================================================================
#
# Loading best model from:
# /home/zak/brats_project/outputs/best_agresunet_brats2017_40epochs_npy_generator.keras
# Processed test patients evaluated: 10
#   0%|                                                                                            | 0/10 [00:00<?, ?it/s]E0000 00:00:1778722649.782829    1161 cuda_timer.cc:87] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 100%|███████████████████████████████████████████████████████████████████████████████████| 10/10 [01:47<00:00, 10.78s/it]
# Per-patient 3D Dice:
#      Dataset              Patient   Dice WT   Dice TC       Dice ET
# 0  brats2017     Brats17_2013_5_1  0.817348  0.850483  8.760352e-01
# 1  brats2017  Brats17_CBICA_ATB_1  0.835515  0.886556  8.321429e-01
# 2  brats2017  Brats17_CBICA_ALN_1  0.845573  0.901128  7.374087e-01
# 3  brats2017  Brats17_CBICA_ANP_1  0.770707  0.799333  7.410377e-01
# 4  brats2017  Brats17_CBICA_APZ_1  0.745419  0.918246  8.313576e-01
# 5  brats2017   Brats17_TCIA_491_1  0.804932  0.927093  9.257725e-01
# 6  brats2017     Brats17_2013_3_1  0.878924  0.857433  8.451459e-01
# 7  brats2017   Brats17_TCIA_387_1  0.882161  0.640191  5.802048e-01
# 8  brats2017   Brats17_TCIA_623_1  0.914500  0.845597  1.858391e-11
# 9  brats2017  Brats17_CBICA_ALU_1  0.816993  0.877630  8.401180e-01
# 3D volumetric Dice summary:
#      Dataset Region Labels used internally  Mean 3D Dice  \
# 0  brats2017     WT                  1,2,3      0.831207
# 1  brats2017     TC                    1,3      0.850369
# 2  brats2017     ET                      3      0.720922
#
#    Paper AGResU-Net Dice  Patients evaluated  Difference from paper
# 0                  0.880                  10              -0.048793
# 1                  0.781                  10               0.069369
# 2                  0.749                  10              -0.028078
# Saved 3D patient results to: /home/zak/brats_project/outputs/volumetric_dice_3d_patients_brats2017.csv
# Saved 3D summary to: /home/zak/brats_project/outputs/volumetric_dice_3d_summary_brats2017.csv
#
# ================================================================================
# 3D VOLUMETRIC DICE EVALUATION: brats2018
# ================================================================================
#
# Loading best model from:
# /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
# Processed test patients evaluated: 10
# 100%|███████████████████████████████████████████████████████████████████████████████████| 10/10 [01:45<00:00, 10.56s/it]
# Per-patient 3D Dice:
#      Dataset               Patient   Dice WT   Dice TC   Dice ET
# 0  brats2018      Brats18_2013_5_1  0.827940  0.860074  0.890555
# 1  brats2018   Brats18_CBICA_ATB_1  0.864003  0.880363  0.830084
# 2  brats2018   Brats18_CBICA_ALN_1  0.839495  0.909494  0.734483
# 3  brats2018   Brats18_CBICA_ANP_1  0.768283  0.744102  0.698779
# 4  brats2018   Brats18_CBICA_APZ_1  0.709826  0.920936  0.837691
# 5  brats2018  Brats18_TCIA08_234_1  0.849498  0.905320  0.896066
# 6  brats2018      Brats18_2013_3_1  0.878870  0.925953  0.859236
# 7  brats2018      Brats18_2013_2_1  0.784647  0.877296  0.834052
# 8  brats2018  Brats18_TCIA10_330_1  0.938355  0.910244  0.392673
# 9  brats2018  Brats18_TCIA12_249_1  0.934233  0.861617  0.029412
# 3D volumetric Dice summary:
#      Dataset Region Labels used internally  Mean 3D Dice  \
# 0  brats2018     WT                  1,2,3      0.839515
# 1  brats2018     TC                    1,3      0.879540
# 2  brats2018     ET                      3      0.700303
#
#    Paper AGResU-Net Dice  Patients evaluated  Difference from paper
# 0                  0.872                  10              -0.032485
# 1                  0.808                  10               0.071540
# 2                  0.772                  10              -0.071697
# Saved 3D patient results to: /home/zak/brats_project/outputs/volumetric_dice_3d_patients_brats2018.csv
# Saved 3D summary to: /home/zak/brats_project/outputs/volumetric_dice_3d_summary_brats2018.csv
#
# ================================================================================
# 3D VOLUMETRIC DICE EVALUATION: brats2019
# ================================================================================
#
# Loading best model from:
# /home/zak/brats_project/outputs/best_agresunet_brats2019_40epochs_npy_generator.keras
# Processed test patients evaluated: 10
# 100%|███████████████████████████████████████████████████████████████████████████████████| 10/10 [01:47<00:00, 10.72s/it]
# Per-patient 3D Dice:
#      Dataset      Patient   Dice WT   Dice TC   Dice ET
# 0  brats2019  BraTS19_200  0.730409  0.890582  0.880746
# 1  brats2019  BraTS19_245  0.948265  0.934753  0.832351
# 2  brats2019  BraTS19_296  0.798934  0.665647  0.287742
# 3  brats2019  BraTS19_325  0.881797  0.126132  0.543253
# 4  brats2019  BraTS19_174  0.943998  0.964976  0.942597
# 5  brats2019  BraTS19_111  0.893112  0.905841  0.849307
# 6  brats2019  BraTS19_272  0.231307  0.213158  0.275455
# 7  brats2019  BraTS19_230  0.932748  0.970920  0.965537
# 8  brats2019  BraTS19_094  0.697290  0.384991  0.532464
# 9  brats2019  BraTS19_031  0.928378  0.915717  0.871277
# 3D volumetric Dice summary:
#      Dataset Region Labels used internally  Mean 3D Dice  \
# 0  brats2019     WT                  1,2,3      0.798624
# 1  brats2019     TC                    1,3      0.697272
# 2  brats2019     ET                      3      0.698073
#
#    Paper AGResU-Net Dice  Patients evaluated  Difference from paper
# 0                  0.870                  10              -0.071376
# 1                  0.777                  10              -0.079728
# 2                  0.709                  10              -0.010927
# Saved 3D patient results to: /home/zak/brats_project/outputs/volumetric_dice_3d_patients_brats2019.csv
# Saved 3D summary to: /home/zak/brats_project/outputs/volumetric_dice_3d_summary_brats2019.csv
#
# Combined 3D volumetric Dice patient results:
#       Dataset               Patient   Dice WT   Dice TC       Dice ET
# 0   brats2017      Brats17_2013_5_1  0.817348  0.850483  8.760352e-01
# 1   brats2017   Brats17_CBICA_ATB_1  0.835515  0.886556  8.321429e-01
# 2   brats2017   Brats17_CBICA_ALN_1  0.845573  0.901128  7.374087e-01
# 3   brats2017   Brats17_CBICA_ANP_1  0.770707  0.799333  7.410377e-01
# 4   brats2017   Brats17_CBICA_APZ_1  0.745419  0.918246  8.313576e-01
# 5   brats2017    Brats17_TCIA_491_1  0.804932  0.927093  9.257725e-01
# 6   brats2017      Brats17_2013_3_1  0.878924  0.857433  8.451459e-01
# 7   brats2017    Brats17_TCIA_387_1  0.882161  0.640191  5.802048e-01
# 8   brats2017    Brats17_TCIA_623_1  0.914500  0.845597  1.858391e-11
# 9   brats2017   Brats17_CBICA_ALU_1  0.816993  0.877630  8.401180e-01
# 10  brats2018      Brats18_2013_5_1  0.827940  0.860074  8.905549e-01
# 11  brats2018   Brats18_CBICA_ATB_1  0.864003  0.880363  8.300843e-01
# 12  brats2018   Brats18_CBICA_ALN_1  0.839495  0.909494  7.344828e-01
# 13  brats2018   Brats18_CBICA_ANP_1  0.768283  0.744102  6.987785e-01
# 14  brats2018   Brats18_CBICA_APZ_1  0.709826  0.920936  8.376910e-01
# 15  brats2018  Brats18_TCIA08_234_1  0.849498  0.905320  8.960659e-01
# 16  brats2018      Brats18_2013_3_1  0.878870  0.925953  8.592364e-01
# 17  brats2018      Brats18_2013_2_1  0.784647  0.877296  8.340522e-01
# 18  brats2018  Brats18_TCIA10_330_1  0.938355  0.910244  3.926734e-01
# 19  brats2018  Brats18_TCIA12_249_1  0.934233  0.861617  2.941176e-02
# 20  brats2019           BraTS19_200  0.730409  0.890582  8.807463e-01
# 21  brats2019           BraTS19_245  0.948265  0.934753  8.323507e-01
# 22  brats2019           BraTS19_296  0.798934  0.665647  2.877419e-01
# 23  brats2019           BraTS19_325  0.881797  0.126132  5.432526e-01
# 24  brats2019           BraTS19_174  0.943998  0.964976  9.425971e-01
# 25  brats2019           BraTS19_111  0.893112  0.905841  8.493075e-01
# 26  brats2019           BraTS19_272  0.231307  0.213158  2.754550e-01
# 27  brats2019           BraTS19_230  0.932748  0.970920  9.655373e-01
# 28  brats2019           BraTS19_094  0.697290  0.384991  5.324640e-01
# 29  brats2019           BraTS19_031  0.928378  0.915717  8.712766e-01
# Combined 3D volumetric Dice summary:
#      Dataset Region Labels used internally  Mean 3D Dice  \
# 0  brats2017     WT                  1,2,3      0.831207
# 1  brats2017     TC                    1,3      0.850369
# 2  brats2017     ET                      3      0.720922
# 3  brats2018     WT                  1,2,3      0.839515
# 4  brats2018     TC                    1,3      0.879540
# 5  brats2018     ET                      3      0.700303
# 6  brats2019     WT                  1,2,3      0.798624
# 7  brats2019     TC                    1,3      0.697272
# 8  brats2019     ET                      3      0.698073
#
#    Paper AGResU-Net Dice  Patients evaluated  Difference from paper
# 0                  0.880                  10              -0.048793
# 1                  0.781                  10               0.069369
# 2                  0.749                  10              -0.028078
# 3                  0.872                  10              -0.032485
# 4                  0.808                  10               0.071540
# 5                  0.772                  10              -0.071697
# 6                  0.870                  10              -0.071376
# 7                  0.777                  10              -0.079728
# 8                  0.709                  10              -0.010927
# Saved combined 3D patient results to: /home/zak/brats_project/outputs/volumetric_dice_3d_patients_all_datasets.csv
# Saved combined 3D summary to: /home/zak/brats_project/outputs/volumetric_dice_3d_summary_all_datasets.csv

# %%
# ============================================================
# Cell 13: Final result table for all datasets
# and comparison with the paper
# ============================================================

# Paper AGResU-Net values from the paper
# BraTS 2017 validation:
# Dice WT/TC/ET = 0.880, 0.781, 0.749
# HD95 WT/TC/ET = 6.87, 9.31, 3.74
#
# BraTS 2018 validation:
# Dice WT/TC/ET = 0.872, 0.808, 0.772
# HD95 WT/TC/ET = 5.62, 8.36, 3.57
#
# BraTS 2019 validation:
# Dice WT/TC/ET = 0.870, 0.777, 0.709
# HD95 is not directly reported in Table 8

paper_values = {
    "brats2017": {
        "Dice WT": 0.880,
        "Dice TC": 0.781,
        "Dice ET": 0.749,
        "HD95 WT": 6.87,
        "HD95 TC": 9.31,
        "HD95 ET": 3.74
    },
    "brats2018": {
        "Dice WT": 0.872,
        "Dice TC": 0.808,
        "Dice ET": 0.772,
        "HD95 WT": 5.62,
        "HD95 TC": 8.36,
        "HD95 ET": 3.57
    },
    "brats2019": {
        "Dice WT": 0.870,
        "Dice TC": 0.777,
        "Dice ET": 0.709,
        "HD95 WT": "Not reported in Table 8",
        "HD95 TC": "Not reported in Table 8",
        "HD95 ET": "Not reported in Table 8"
    }
}


all_comparisons = []
all_summaries = []

for dataset_name in ["brats2017", "brats2018", "brats2019"]:

    print("\n" + "=" * 80)
    print("FINAL SUMMARY FOR:", dataset_name)
    print("=" * 80)

    # Get this dataset result from Cell 12
    dataset_result = final_results_table[
        final_results_table["Dataset"] == dataset_name
    ].iloc[0]

    dataset_hd95 = final_hd95_table[
        final_hd95_table["Dataset"] == dataset_name
    ]

    # Our hard Dice values
    our_hard_wt = float(dataset_result["Hard Dice WT"])
    our_hard_tc = float(dataset_result["Hard Dice TC"])
    our_hard_et = float(dataset_result["Hard Dice ET"])

    # Our soft Dice values from training log best epoch
    our_soft_wt = float(dataset_result["Soft Dice WT"])
    our_soft_tc = float(dataset_result["Soft Dice TC"])
    our_soft_et = float(dataset_result["Soft Dice ET"])

    # Our HD95 values
    our_hd95_wt = float(dataset_hd95.loc[dataset_hd95["Region"] == "WT", "Mean HD95"].iloc[0])
    our_hd95_tc = float(dataset_hd95.loc[dataset_hd95["Region"] == "TC", "Mean HD95"].iloc[0])
    our_hd95_et = float(dataset_hd95.loc[dataset_hd95["Region"] == "ET", "Mean HD95"].iloc[0])

    # Paper values for this dataset
    paper_wt = paper_values[dataset_name]["Dice WT"]
    paper_tc = paper_values[dataset_name]["Dice TC"]
    paper_et = paper_values[dataset_name]["Dice ET"]

    paper_hd95_wt = paper_values[dataset_name]["HD95 WT"]
    paper_hd95_tc = paper_values[dataset_name]["HD95 TC"]
    paper_hd95_et = paper_values[dataset_name]["HD95 ET"]

    final_comparison = pd.DataFrame({
        "Dataset": [
            dataset_name,
            dataset_name,
            dataset_name,
            dataset_name,
            dataset_name,
            dataset_name
        ],
        "Metric": [
            "Dice WT",
            "Dice TC",
            "Dice ET",
            "HD95 WT",
            "HD95 TC",
            "HD95 ET"
        ],
        "Our result": [
            our_hard_wt,
            our_hard_tc,
            our_hard_et,
            our_hd95_wt,
            our_hd95_tc,
            our_hd95_et
        ],
        "Our soft Dice": [
            our_soft_wt,
            our_soft_tc,
            our_soft_et,
            "",
            "",
            ""
        ],
        "Paper AGResU-Net result": [
            paper_wt,
            paper_tc,
            paper_et,
            paper_hd95_wt,
            paper_hd95_tc,
            paper_hd95_et
        ],
        "Difference from paper": [
            our_hard_wt - paper_wt,
            our_hard_tc - paper_tc,
            our_hard_et - paper_et,
            our_hd95_wt - paper_hd95_wt if isinstance(paper_hd95_wt, (int, float)) else "Not calculated",
            our_hd95_tc - paper_hd95_tc if isinstance(paper_hd95_tc, (int, float)) else "Not calculated",
            our_hd95_et - paper_hd95_et if isinstance(paper_hd95_et, (int, float)) else "Not calculated"
        ],
        "Notes": [
            "Hard Dice from our validation slices",
            "Hard Dice from our validation slices",
            "Hard Dice from our validation slices",
            "Our HD95 is 2D validation-slice HD95",
            "Our HD95 is 2D validation-slice HD95",
            "Our HD95 is 2D validation-slice HD95"
        ]
    })

    checkpoint_path = OUTPUT_DIR / f"best_agresunet_{dataset_name}_allpatients_40epochs_preloaded.keras"
    final_model_path = OUTPUT_DIR / f"final_agresunet_{dataset_name}_allpatients_40epochs_preloaded.keras"
    log_path = OUTPUT_DIR / f"training_log_{dataset_name}_allpatients_40epochs_preloaded.csv"

    train_index = DATASET_INDEXES[dataset_name]["train_index"]
    val_index = DATASET_INDEXES[dataset_name]["val_index"]

    train_patients = DATASET_SPLITS[dataset_name]["train_patients"]
    val_patients = DATASET_SPLITS[dataset_name]["val_patients"]
    test_patients = DATASET_SPLITS[dataset_name]["test_patients"]
    all_patients = DATASET_SPLITS[dataset_name]["all_patients"]

    run_summary = pd.DataFrame({
        "Dataset": [dataset_name] * 17,
        "Item": [
            "Dataset",
            "Model",
            "Input shape",
            "Patients found",
            "Training patients",
            "Validation patients",
            "Test patients",
            "Training tumor slices",
            "Validation tumor slices",
            "Training samples used after augmentation",
            "Validation samples used",
            "Epochs trained",
            "Best epoch",
            "Best val_loss",
            "Optimizer",
            "Best model path",
            "Training log path"
        ],
        "Value": [
            dataset_name,
            "AGResU-Net",
            f"{PATCH_SIZE} x {PATCH_SIZE} x 4",
            len(all_patients),
            len(train_patients),
            len(val_patients),
            len(test_patients),
            len(train_index),
            len(val_index),
            len(train_index) * 2,
            len(val_index),
            EPOCHS,
            int(dataset_result["Best epoch"]),
            float(dataset_result["Best val_loss"]),
            f"SGD, learning_rate={LEARNING_RATE_RUN}, momentum={MOMENTUM}",
            str(checkpoint_path),
            str(log_path)
        ]
    })

    print("\nRun summary:")
    display(run_summary)

    print("\nFinal comparison table:")
    display(final_comparison)

    all_summaries.append(run_summary)
    all_comparisons.append(final_comparison)


# Combine all datasets into final tables
final_run_summary_all = pd.concat(all_summaries, ignore_index=True)
final_comparison_all = pd.concat(all_comparisons, ignore_index=True)

print("\n" + "=" * 80)
print("ALL DATASETS FINAL RUN SUMMARY")
print("=" * 80)
display(final_run_summary_all)

print("\n" + "=" * 80)
print("ALL DATASETS FINAL COMPARISON")
print("=" * 80)
display(final_comparison_all)


# Save final tables
summary_path = OUTPUT_DIR / "run_summary_all_datasets.csv"
comparison_path = OUTPUT_DIR / "comparison_with_paper_all_datasets.csv"
hd95_path = OUTPUT_DIR / "hd95_results_all_datasets.csv"
results_path = OUTPUT_DIR / "dice_results_all_datasets.csv"

final_run_summary_all.to_csv(summary_path, index=False)
final_comparison_all.to_csv(comparison_path, index=False)
final_hd95_table.to_csv(hd95_path, index=False)
final_results_table.to_csv(results_path, index=False)

print("\nSaved files:")
print(summary_path)
print(comparison_path)
print(hd95_path)
print(results_path)
# Out:
# ================================================================================
# FINAL SUMMARY FOR: brats2017
# ================================================================================
#
# Run summary:
#       Dataset                                      Item  \
# 0   brats2017                                   Dataset
# 1   brats2017                                     Model
# 2   brats2017                               Input shape
# 3   brats2017                            Patients found
# 4   brats2017                         Training patients
# 5   brats2017                       Validation patients
# 6   brats2017                             Test patients
# 7   brats2017                     Training tumor slices
# 8   brats2017                   Validation tumor slices
# 9   brats2017  Training samples used after augmentation
# 10  brats2017                   Validation samples used
# 11  brats2017                            Epochs trained
# 12  brats2017                                Best epoch
# 13  brats2017                             Best val_loss
# 14  brats2017                                 Optimizer
# 15  brats2017                           Best model path
# 16  brats2017                         Training log path
#
#                                                 Value
# 0                                           brats2017
# 1                                          AGResU-Net
# 2                                       128 x 128 x 4
# 3                                                 285
# 4                                                 171
# 5                                                  57
# 6                                                  57
# 7                                               11085
# 8                                                3621
# 9                                               22170
# 10                                               3621
# 11                                                 40
# 12                                                 37
# 13                                           0.398432
# 14            SGD, learning_rate=0.003, momentum=0.97
# 15  /home/zak/brats_project/outputs/best_agresunet...
# 16  /home/zak/brats_project/outputs/training_log_b...
# Final comparison table:
#      Dataset   Metric  Our result Our soft Dice  Paper AGResU-Net result  \
# 0  brats2017  Dice WT    0.812509      0.887633                    0.880
# 1  brats2017  Dice TC    0.670758      0.791251                    0.781
# 2  brats2017  Dice ET    0.637816      0.833189                    0.749
# 3  brats2017  HD95 WT    9.776387                                  6.870
# 4  brats2017  HD95 TC    6.385866                                  9.310
# 5  brats2017  HD95 ET    4.573255                                  3.740
#
#    Difference from paper                                 Notes
# 0              -0.067491  Hard Dice from our validation slices
# 1              -0.110242  Hard Dice from our validation slices
# 2              -0.111184  Hard Dice from our validation slices
# 3               2.906387  Our HD95 is 2D validation-slice HD95
# 4              -2.924134  Our HD95 is 2D validation-slice HD95
# 5               0.833255  Our HD95 is 2D validation-slice HD95
# ================================================================================
# FINAL SUMMARY FOR: brats2018
# ================================================================================
#
# Run summary:
#       Dataset                                      Item  \
# 0   brats2018                                   Dataset
# 1   brats2018                                     Model
# 2   brats2018                               Input shape
# 3   brats2018                            Patients found
# 4   brats2018                         Training patients
# 5   brats2018                       Validation patients
# 6   brats2018                             Test patients
# 7   brats2018                     Training tumor slices
# 8   brats2018                   Validation tumor slices
# 9   brats2018  Training samples used after augmentation
# 10  brats2018                   Validation samples used
# 11  brats2018                            Epochs trained
# 12  brats2018                                Best epoch
# 13  brats2018                             Best val_loss
# 14  brats2018                                 Optimizer
# 15  brats2018                           Best model path
# 16  brats2018                         Training log path
#
#                                                 Value
# 0                                           brats2018
# 1                                          AGResU-Net
# 2                                       128 x 128 x 4
# 3                                                 285
# 4                                                 171
# 5                                                  57
# 6                                                  57
# 7                                               11157
# 8                                                3587
# 9                                               22314
# 10                                               3587
# 11                                                 40
# 12                                                 29
# 13                                           0.340269
# 14            SGD, learning_rate=0.003, momentum=0.97
# 15  /home/zak/brats_project/outputs/best_agresunet...
# 16  /home/zak/brats_project/outputs/training_log_b...
# Final comparison table:
#      Dataset   Metric  Our result Our soft Dice  Paper AGResU-Net result  \
# 0  brats2018  Dice WT    0.827601      0.876944                    0.872
# 1  brats2018  Dice TC    0.689010      0.802116                    0.808
# 2  brats2018  Dice ET    0.670647      0.834498                    0.772
# 3  brats2018  HD95 WT    8.813345                                  5.620
# 4  brats2018  HD95 TC    6.854973                                  8.360
# 5  brats2018  HD95 ET    6.288176                                  3.570
#
#    Difference from paper                                 Notes
# 0              -0.044399  Hard Dice from our validation slices
# 1              -0.118990  Hard Dice from our validation slices
# 2              -0.101353  Hard Dice from our validation slices
# 3               3.193345  Our HD95 is 2D validation-slice HD95
# 4              -1.505027  Our HD95 is 2D validation-slice HD95
# 5               2.718176  Our HD95 is 2D validation-slice HD95
# ================================================================================
# FINAL SUMMARY FOR: brats2019
# ================================================================================
#
# Run summary:
#       Dataset                                      Item  \
# 0   brats2019                                   Dataset
# 1   brats2019                                     Model
# 2   brats2019                               Input shape
# 3   brats2019                            Patients found
# 4   brats2019                         Training patients
# 5   brats2019                       Validation patients
# 6   brats2019                             Test patients
# 7   brats2019                     Training tumor slices
# 8   brats2019                   Validation tumor slices
# 9   brats2019  Training samples used after augmentation
# 10  brats2019                   Validation samples used
# 11  brats2019                            Epochs trained
# 12  brats2019                                Best epoch
# 13  brats2019                             Best val_loss
# 14  brats2019                                 Optimizer
# 15  brats2019                           Best model path
# 16  brats2019                         Training log path
#
#                                                 Value
# 0                                           brats2019
# 1                                          AGResU-Net
# 2                                       128 x 128 x 4
# 3                                                 335
# 4                                                 201
# 5                                                  67
# 6                                                  67
# 7                                               12912
# 8                                                4339
# 9                                               25824
# 10                                               4339
# 11                                                 40
# 12                                                 40
# 13                                           0.324429
# 14            SGD, learning_rate=0.003, momentum=0.97
# 15  /home/zak/brats_project/outputs/best_agresunet...
# 16  /home/zak/brats_project/outputs/training_log_b...
# Final comparison table:
#      Dataset   Metric  Our result Our soft Dice  Paper AGResU-Net result  \
# 0  brats2019  Dice WT    0.828280      0.895612                     0.87
# 1  brats2019  Dice TC    0.645153      0.856385                    0.777
# 2  brats2019  Dice ET    0.640218       0.82148                    0.709
# 3  brats2019  HD95 WT    8.367290                Not reported in Table 8
# 4  brats2019  HD95 TC    9.753166                Not reported in Table 8
# 5  brats2019  HD95 ET    9.354920                Not reported in Table 8
#
#   Difference from paper                                 Notes
# 0              -0.04172  Hard Dice from our validation slices
# 1             -0.131847  Hard Dice from our validation slices
# 2             -0.068782  Hard Dice from our validation slices
# 3        Not calculated  Our HD95 is 2D validation-slice HD95
# 4        Not calculated  Our HD95 is 2D validation-slice HD95
# 5        Not calculated  Our HD95 is 2D validation-slice HD95
# ================================================================================
# ALL DATASETS FINAL RUN SUMMARY
# ================================================================================
#       Dataset                                      Item  \
# 0   brats2017                                   Dataset
# 1   brats2017                                     Model
# 2   brats2017                               Input shape
# 3   brats2017                            Patients found
# 4   brats2017                         Training patients
# 5   brats2017                       Validation patients
# 6   brats2017                             Test patients
# 7   brats2017                     Training tumor slices
# 8   brats2017                   Validation tumor slices
# 9   brats2017  Training samples used after augmentation
# 10  brats2017                   Validation samples used
# 11  brats2017                            Epochs trained
# 12  brats2017                                Best epoch
# 13  brats2017                             Best val_loss
# 14  brats2017                                 Optimizer
# 15  brats2017                           Best model path
# 16  brats2017                         Training log path
# 17  brats2018                                   Dataset
# 18  brats2018                                     Model
# 19  brats2018                               Input shape
# 20  brats2018                            Patients found
# 21  brats2018                         Training patients
# 22  brats2018                       Validation patients
# 23  brats2018                             Test patients
# 24  brats2018                     Training tumor slices
# 25  brats2018                   Validation tumor slices
# 26  brats2018  Training samples used after augmentation
# 27  brats2018                   Validation samples used
# 28  brats2018                            Epochs trained
# 29  brats2018                                Best epoch
# 30  brats2018                             Best val_loss
# 31  brats2018                                 Optimizer
# 32  brats2018                           Best model path
# 33  brats2018                         Training log path
# 34  brats2019                                   Dataset
# 35  brats2019                                     Model
# 36  brats2019                               Input shape
# 37  brats2019                            Patients found
# 38  brats2019                         Training patients
# 39  brats2019                       Validation patients
# 40  brats2019                             Test patients
# 41  brats2019                     Training tumor slices
# 42  brats2019                   Validation tumor slices
# 43  brats2019  Training samples used after augmentation
# 44  brats2019                   Validation samples used
# 45  brats2019                            Epochs trained
# 46  brats2019                                Best epoch
# 47  brats2019                             Best val_loss
# 48  brats2019                                 Optimizer
# 49  brats2019                           Best model path
# 50  brats2019                         Training log path
#
#                                                 Value
# 0                                           brats2017
# 1                                          AGResU-Net
# 2                                       128 x 128 x 4
# 3                                                 285
# 4                                                 171
# 5                                                  57
# 6                                                  57
# 7                                               11085
# 8                                                3621
# 9                                               22170
# 10                                               3621
# 11                                                 40
# 12                                                 37
# 13                                           0.398432
# 14            SGD, learning_rate=0.003, momentum=0.97
# 15  /home/zak/brats_project/outputs/best_agresunet...
# 16  /home/zak/brats_project/outputs/training_log_b...
# 17                                          brats2018
# 18                                         AGResU-Net
# 19                                      128 x 128 x 4
# 20                                                285
# 21                                                171
# 22                                                 57
# 23                                                 57
# 24                                              11157
# 25                                               3587
# 26                                              22314
# 27                                               3587
# 28                                                 40
# 29                                                 29
# 30                                           0.340269
# 31            SGD, learning_rate=0.003, momentum=0.97
# 32  /home/zak/brats_project/outputs/best_agresunet...
# 33  /home/zak/brats_project/outputs/training_log_b...
# 34                                          brats2019
# 35                                         AGResU-Net
# 36                                      128 x 128 x 4
# 37                                                335
# 38                                                201
# 39                                                 67
# 40                                                 67
# 41                                              12912
# 42                                               4339
# 43                                              25824
# 44                                               4339
# 45                                                 40
# 46                                                 40
# 47                                           0.324429
# 48            SGD, learning_rate=0.003, momentum=0.97
# 49  /home/zak/brats_project/outputs/best_agresunet...
# 50  /home/zak/brats_project/outputs/training_log_b...
# ================================================================================
# ALL DATASETS FINAL COMPARISON
# ================================================================================
#       Dataset   Metric  Our result Our soft Dice  Paper AGResU-Net result  \
# 0   brats2017  Dice WT    0.812509      0.887633                     0.88
# 1   brats2017  Dice TC    0.670758      0.791251                    0.781
# 2   brats2017  Dice ET    0.637816      0.833189                    0.749
# 3   brats2017  HD95 WT    9.776387                                   6.87
# 4   brats2017  HD95 TC    6.385866                                   9.31
# 5   brats2017  HD95 ET    4.573255                                   3.74
# 6   brats2018  Dice WT    0.827601      0.876944                    0.872
# 7   brats2018  Dice TC    0.689010      0.802116                    0.808
# 8   brats2018  Dice ET    0.670647      0.834498                    0.772
# 9   brats2018  HD95 WT    8.813345                                   5.62
# 10  brats2018  HD95 TC    6.854973                                   8.36
# 11  brats2018  HD95 ET    6.288176                                   3.57
# 12  brats2019  Dice WT    0.828280      0.895612                     0.87
# 13  brats2019  Dice TC    0.645153      0.856385                    0.777
# 14  brats2019  Dice ET    0.640218       0.82148                    0.709
# 15  brats2019  HD95 WT    8.367290                Not reported in Table 8
# 16  brats2019  HD95 TC    9.753166                Not reported in Table 8
# 17  brats2019  HD95 ET    9.354920                Not reported in Table 8
#
#    Difference from paper                                 Notes
# 0              -0.067491  Hard Dice from our validation slices
# 1              -0.110242  Hard Dice from our validation slices
# 2              -0.111184  Hard Dice from our validation slices
# 3               2.906387  Our HD95 is 2D validation-slice HD95
# 4              -2.924134  Our HD95 is 2D validation-slice HD95
# 5               0.833255  Our HD95 is 2D validation-slice HD95
# 6              -0.044399  Hard Dice from our validation slices
# 7               -0.11899  Hard Dice from our validation slices
# 8              -0.101353  Hard Dice from our validation slices
# 9               3.193345  Our HD95 is 2D validation-slice HD95
# 10             -1.505027  Our HD95 is 2D validation-slice HD95
# 11              2.718176  Our HD95 is 2D validation-slice HD95
# 12              -0.04172  Hard Dice from our validation slices
# 13             -0.131847  Hard Dice from our validation slices
# 14             -0.068782  Hard Dice from our validation slices
# 15        Not calculated  Our HD95 is 2D validation-slice HD95
# 16        Not calculated  Our HD95 is 2D validation-slice HD95
# 17        Not calculated  Our HD95 is 2D validation-slice HD95
# Saved files:
# /home/zak/brats_project/outputs/run_summary_all_datasets.csv
# /home/zak/brats_project/outputs/comparison_with_paper_all_datasets.csv
# /home/zak/brats_project/outputs/hd95_results_all_datasets.csv
# /home/zak/brats_project/outputs/dice_results_all_datasets.csv

# %%
# ============================================================
# Cell 14: Final summary and plots for all 3 datasets
# ============================================================

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Make sure these were created from Cell 12 / Cell 13:
# final_results_table
# final_hd95_table
# final_comparison_all

print("Final Dice results from evaluation:")
display(final_results_table)

print("\nFinal HD95 results:")
display(final_hd95_table)


# ------------------------------------------------------------
# 1) Build one clean summary table
# ------------------------------------------------------------

summary_rows = []

for dataset_name in ["brats2017", "brats2018", "brats2019"]:

    dataset_result = final_results_table[
        final_results_table["Dataset"] == dataset_name
    ].iloc[0]

    dataset_hd95 = final_hd95_table[
        final_hd95_table["Dataset"] == dataset_name
    ]

    hd95_wt = dataset_hd95.loc[dataset_hd95["Region"] == "WT", "Mean HD95"].iloc[0]
    hd95_tc = dataset_hd95.loc[dataset_hd95["Region"] == "TC", "Mean HD95"].iloc[0]
    hd95_et = dataset_hd95.loc[dataset_hd95["Region"] == "ET", "Mean HD95"].iloc[0]

    summary_rows.append({
        "Dataset": dataset_name,
        "Best epoch": dataset_result["Best epoch"],
        "Best val_loss": dataset_result["Best val_loss"],

        "Soft Dice WT": dataset_result["Soft Dice WT"],
        "Soft Dice TC": dataset_result["Soft Dice TC"],
        "Soft Dice ET": dataset_result["Soft Dice ET"],

        "Hard Dice WT": dataset_result["Hard Dice WT"],
        "Hard Dice TC": dataset_result["Hard Dice TC"],
        "Hard Dice ET": dataset_result["Hard Dice ET"],

        "HD95 WT": hd95_wt,
        "HD95 TC": hd95_tc,
        "HD95 ET": hd95_et
    })

final_summary_all_datasets = pd.DataFrame(summary_rows)

print("\nFinal summary for all 3 datasets:")
display(final_summary_all_datasets)


# Save summary table
summary_all_path = OUTPUT_DIR / "final_summary_all_3_datasets.csv"
final_summary_all_datasets.to_csv(summary_all_path, index=False)

print("\nSaved final summary to:")
print(summary_all_path)
# Out:
# Final Dice results from evaluation:
#      Dataset                                    Run  Best epoch  \
# 0  brats2017  brats2017 full 40-epoch preloaded run          37
# 1  brats2018  brats2018 full 40-epoch preloaded run          29
# 2  brats2019  brats2019 full 40-epoch preloaded run          40
#
#    Validation samples  Best val_loss  Soft Dice WT  Soft Dice TC  \
# 0                1000       0.398432      0.887633      0.791251
# 1                1000       0.340269      0.876944      0.802116
# 2                1000       0.324429      0.895612      0.856385
#
#    Soft Dice ET  Hard Dice WT  Hard Dice TC  Hard Dice ET   HD95 WT   HD95 TC  \
# 0      0.833189      0.812509      0.670758      0.637816  9.776387  6.385866
# 1      0.834498      0.827601      0.689010      0.670647  8.813345  6.854973
# 2      0.821480      0.828280      0.645153      0.640218  8.367290  9.753166
#
#     HD95 ET
# 0  4.573255
# 1  6.288176
# 2  9.354920
# Final HD95 results:
#      Dataset Region Labels used  Mean HD95  Valid cases  Total cases
# 0  brats2017     WT       1,2,3   9.776387          979         1000
# 1  brats2017     TC         1,3   6.385866          614         1000
# 2  brats2017     ET           3   4.573255          525         1000
# 3  brats2018     WT       1,2,3   8.813345          976         1000
# 4  brats2018     TC         1,3   6.854973          615         1000
# 5  brats2018     ET           3   6.288176          573         1000
# 6  brats2019     WT       1,2,3   8.367290          973         1000
# 7  brats2019     TC         1,3   9.753166          669         1000
# 8  brats2019     ET           3   9.354920          546         1000
# Final summary for all 3 datasets:
#      Dataset  Best epoch  Best val_loss  Soft Dice WT  Soft Dice TC  \
# 0  brats2017          37       0.398432      0.887633      0.791251
# 1  brats2018          29       0.340269      0.876944      0.802116
# 2  brats2019          40       0.324429      0.895612      0.856385
#
#    Soft Dice ET  Hard Dice WT  Hard Dice TC  Hard Dice ET   HD95 WT   HD95 TC  \
# 0      0.833189      0.812509      0.670758      0.637816  9.776387  6.385866
# 1      0.834498      0.827601      0.689010      0.670647  8.813345  6.854973
# 2      0.821480      0.828280      0.645153      0.640218  8.367290  9.753166
#
#     HD95 ET
# 0  4.573255
# 1  6.288176
# 2  9.354920
# Saved final summary to:
# /home/zak/brats_project/outputs/final_summary_all_3_datasets.csv

# %%
# ============================================================
# Plot 1: Hard Dice comparison for WT, TC, ET
# ============================================================

datasets = final_summary_all_datasets["Dataset"]

x = np.arange(len(datasets))
width = 0.25

plt.figure(figsize=(9, 5))

plt.bar(x - width, final_summary_all_datasets["Hard Dice WT"], width, label="WT")
plt.bar(x, final_summary_all_datasets["Hard Dice TC"], width, label="TC")
plt.bar(x + width, final_summary_all_datasets["Hard Dice ET"], width, label="ET")

plt.xticks(x, datasets)
plt.ylabel("Hard Dice")
plt.title("Hard Dice comparison across BraTS 2017, 2018, and 2019")
plt.ylim(0, 1)
plt.legend()
plt.grid(axis="y", alpha=0.3)

dice_plot_path = OUTPUT_DIR / "hard_dice_comparison_all_datasets.png"
plt.savefig(dice_plot_path, dpi=200, bbox_inches="tight")

plt.show()

print("Saved Dice plot to:")
print(dice_plot_path)
# Out:
# Saved Dice plot to:
# /home/zak/brats_project/outputs/hard_dice_comparison_all_datasets.png

# %%
# ============================================================
# Plot 2: Soft Dice comparison for WT, TC, ET
# ============================================================

datasets = final_summary_all_datasets["Dataset"]

x = np.arange(len(datasets))
width = 0.25

plt.figure(figsize=(9, 5))

plt.bar(x - width, final_summary_all_datasets["Soft Dice WT"], width, label="WT")
plt.bar(x, final_summary_all_datasets["Soft Dice TC"], width, label="TC")
plt.bar(x + width, final_summary_all_datasets["Soft Dice ET"], width, label="ET")

plt.xticks(x, datasets)
plt.ylabel("Soft Dice")
plt.title("Soft Dice comparison across BraTS 2017, 2018, and 2019")
plt.ylim(0, 1)
plt.legend()
plt.grid(axis="y", alpha=0.3)

soft_dice_plot_path = OUTPUT_DIR / "soft_dice_comparison_all_datasets.png"
plt.savefig(soft_dice_plot_path, dpi=200, bbox_inches="tight")

plt.show()

print("Saved Soft Dice plot to:")
print(soft_dice_plot_path)
# Out:
# Saved Soft Dice plot to:
# /home/zak/brats_project/outputs/soft_dice_comparison_all_datasets.png

# %%
# ============================================================
# Plot 3: HD95 comparison for WT, TC, ET
# ============================================================

datasets = final_summary_all_datasets["Dataset"]

x = np.arange(len(datasets))
width = 0.25

plt.figure(figsize=(9, 5))

plt.bar(x - width, final_summary_all_datasets["HD95 WT"], width, label="WT")
plt.bar(x, final_summary_all_datasets["HD95 TC"], width, label="TC")
plt.bar(x + width, final_summary_all_datasets["HD95 ET"], width, label="ET")

plt.xticks(x, datasets)
plt.ylabel("HD95")
plt.title("HD95 comparison across BraTS 2017, 2018, and 2019")
plt.legend()
plt.grid(axis="y", alpha=0.3)

hd95_plot_path = OUTPUT_DIR / "hd95_comparison_all_datasets.png"
plt.savefig(hd95_plot_path, dpi=200, bbox_inches="tight")

plt.show()

print("Saved HD95 plot to:")
print(hd95_plot_path)
# Out:
# Saved HD95 plot to:
# /home/zak/brats_project/outputs/hd95_comparison_all_datasets.png

# %%
# ============================================================
# Cell 15: Final prediction visualization for all datasets
# Uses preprocessed .npy validation samples
# ============================================================

import matplotlib.pyplot as plt
import gc

def visualize_predictions_one_dataset(dataset_name, num_examples=3):
    print("\n" + "=" * 80)
    print("VISUALIZING PREDICTIONS FOR:", dataset_name)
    print("=" * 80)

    # Correct new checkpoint path
    checkpoint_path = OUTPUT_DIR / f"best_agresunet_{dataset_name}_40epochs_npy_generator.keras"

    print("\nLoading best model from:")
    print(checkpoint_path)

    if not checkpoint_path.exists():
        print("Model checkpoint not found:", checkpoint_path)
        return None

    # Load validation data from preprocessed .npy files
    print("\nReloading validation data from preprocessed .npy files...")

    X_val_full, y_val_full = load_validation_from_processed(
        dataset_name,
        max_eval_slices=1000
    )

    print("X_val_full:", X_val_full.shape)
    print("y_val_full:", y_val_full.shape)

    if len(X_val_full) == 0:
        print("No validation samples loaded.")
        return None

    # Load best model
    best_model = tf.keras.models.load_model(
        checkpoint_path,
        compile=False
    )

    # Predict
    pred_probs = best_model.predict(
        X_val_full,
        batch_size=8,
        verbose=1
    )

    true_masks = np.argmax(y_val_full, axis=-1)
    pred_masks = np.argmax(pred_probs, axis=-1)

    print("\nTrue labels:", np.unique(true_masks))
    print("Predicted labels:", np.unique(pred_masks))

    # Choose validation slices with largest tumor area
    tumor_pixels = np.sum(true_masks > 0, axis=(1, 2))
    example_ids = np.argsort(tumor_pixels)[-num_examples:][::-1]

    print("\nExamples selected:", example_ids)
    print("Tumor pixels in selected examples:", tumor_pixels[example_ids])

    plt.figure(figsize=(16, 10))

    for row, i in enumerate(example_ids):
        flair = X_val_full[i, :, :, 0]
        t1ce = X_val_full[i, :, :, 2]
        true_mask = true_masks[i]
        pred_mask = pred_masks[i]

        plt.subplot(len(example_ids), 5, row * 5 + 1)
        plt.imshow(flair, cmap="gray")
        plt.title("Flair")
        plt.axis("off")

        plt.subplot(len(example_ids), 5, row * 5 + 2)
        plt.imshow(t1ce, cmap="gray")
        plt.title("T1ce")
        plt.axis("off")

        plt.subplot(len(example_ids), 5, row * 5 + 3)
        plt.imshow(true_mask)
        plt.title("Ground truth")
        plt.axis("off")

        plt.subplot(len(example_ids), 5, row * 5 + 4)
        plt.imshow(pred_mask)
        plt.title("Prediction")
        plt.axis("off")

        plt.subplot(len(example_ids), 5, row * 5 + 5)
        plt.imshow(flair, cmap="gray")
        plt.imshow(pred_mask, alpha=0.45)
        plt.title("Prediction overlay")
        plt.axis("off")

    plt.suptitle(f"AGResU-Net {dataset_name} validation predictions", fontsize=16)
    plt.tight_layout()

    visual_path = OUTPUT_DIR / f"final_prediction_visualization_{dataset_name}.png"
    plt.savefig(visual_path, dpi=200, bbox_inches="tight")
    plt.show()

    print("\nSaved visualization to:")
    print(visual_path)

    del X_val_full, y_val_full
    del pred_probs, true_masks, pred_masks
    del best_model
    gc.collect()
    tf.keras.backend.clear_session()

    return visual_path

# %%
# ============================================================
# Cell 16: Run final visualization for BraTS 2017, 2018, 2019
# ============================================================

visual_paths = {}

for dataset_name in ["brats2017", "brats2018", "brats2019"]:
    visual_paths[dataset_name] = visualize_predictions_one_dataset(
        dataset_name,
        num_examples=3
    )

print("\nAll visualizations saved:")

for dataset_name, path in visual_paths.items():
    print(dataset_name, ":", path)
# Out:
# ================================================================================
# VISUALIZING PREDICTIONS FOR: brats2017
# ================================================================================
#
# Loading best model from:
# /home/zak/brats_project/outputs/best_agresunet_brats2017_40epochs_npy_generator.keras
#
# Reloading validation data from preprocessed .npy files...
# Processed validation patients: 57
#  26%|█████████████████████▊                                                             | 15/57 [00:02<00:07,  5.38it/s]
# X_val_full: (1000, 128, 128, 4)
# y_val_full: (1000, 128, 128, 4)
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step
#
# True labels: [0 1 2 3]
# Predicted labels: [0 1 2 3]
#
# Examples selected: [904 905 910]
# Tumor pixels in selected examples: [4941 4926 4867]
# Saved visualization to:
# /home/zak/brats_project/outputs/final_prediction_visualization_brats2017.png
#
# ================================================================================
# VISUALIZING PREDICTIONS FOR: brats2018
# ================================================================================
#
# Loading best model from:
# /home/zak/brats_project/outputs/best_agresunet_brats2018_40epochs_npy_generator.keras
#
# Reloading validation data from preprocessed .npy files...
# Processed validation patients: 57
#  26%|█████████████████████▊                                                             | 15/57 [00:02<00:07,  5.52it/s]
# X_val_full: (1000, 128, 128, 4)
# y_val_full: (1000, 128, 128, 4)
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step
#
# True labels: [0 1 2 3]
# Predicted labels: [0 1 2 3]
#
# Examples selected: [518 517 520]
# Tumor pixels in selected examples: [4423 4410 4408]
# Saved visualization to:
# /home/zak/brats_project/outputs/final_prediction_visualization_brats2018.png
#
# ================================================================================
# VISUALIZING PREDICTIONS FOR: brats2019
# ================================================================================
#
# Loading best model from:
# /home/zak/brats_project/outputs/best_agresunet_brats2019_40epochs_npy_generator.keras
#
# Reloading validation data from preprocessed .npy files...
# Processed validation patients: 67
#  22%|██████████████████▌                                                                | 15/67 [00:01<00:06,  8.03it/s]
# X_val_full: (1000, 128, 128, 4)
# y_val_full: (1000, 128, 128, 4)
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step
#
# True labels: [0 1 2 3]
# Predicted labels: [0 1 2 3]
#
# Examples selected: [456 451 441]
# Tumor pixels in selected examples: [5258 5156 5133]
# Saved visualization to:
# /home/zak/brats_project/outputs/final_prediction_visualization_brats2019.png
#
# All visualizations saved:
# brats2017 : /home/zak/brats_project/outputs/final_prediction_visualization_brats2017.png
# brats2018 : /home/zak/brats_project/outputs/final_prediction_visualization_brats2018.png
# brats2019 : /home/zak/brats_project/outputs/final_prediction_visualization_brats2019.png
